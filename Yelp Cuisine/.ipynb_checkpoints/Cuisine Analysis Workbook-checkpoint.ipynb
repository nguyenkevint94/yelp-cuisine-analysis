# %% [markdown]
# # Dependencies

# %%
# Dependencies
import pandas as pd
import re
import requests
import math 
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from pprint import pprint
from config import api_key, plotly_key
from yelpapi import YelpAPI

# %% [markdown]
# # Ideas
# <ul><li>Average rating vs. category
# <li>Average rating vs. price rating
# <li>Number of restaurant categories per city
# <li>Review Count vs. city

# %% [markdown]
# # Useful Links
# <ul><li><a href="https://alcidanalytics.com/p/geographic-heatmap-in-python">Heat maps</a>

# %% [markdown]
# # API Call

# %%
# API call to Yelp API
yelp_api = YelpAPI(api_key)
# Input string for location search
input_string = input("Search query: ")
api_call = yelp_api.search_query(location=input_string, limit=50)

# API Call to Plotly 
plotly.tools.set_credentials_file(username='nguyenkevint94', api_key=plotly_key)

# Delete hashtag to view the contents of api_call
pprint(api_call)
# Out:
# Search query: Brooklyn
# {'businesses': [{'alias': 'peter-luger-brooklyn-2',
#                  'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#                  'coordinates': {'latitude': 40.709945,
#                                  'longitude': -73.962478},
#                  'display_phone': '(718) 387-7400',
#                  'distance': 5711.937381508804,
#                  'id': '4yPqqJDJOQX69gC66YUDkA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DnReRUkXRtsmKycQEYl0pg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '178 Broadway',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['178 Broadway',
#                                                   'Brooklyn, NY 11211'],
#                               'state': 'NY',
#                               'zip_code': '11211'},
#                  'name': 'Peter Luger',
#                  'phone': '+17183877400',
#                  'price': '$$$$',
#                  'rating': 4.0,
#                  'review_count': 5108,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/peter-luger-brooklyn-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'dough-brooklyn',
#                  'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 40.6890699083996,
#                                  'longitude': -73.957078},
#                  'display_phone': '(347) 533-7544',
#                  'distance': 3487.798692619505,
#                  'id': 'P58WuRP1AGD9ruE2bZ2urw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iuBTjvTYM2kQ5HunomGEvA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '448 Franklin Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['448 Franklin Ave',
#                                                   'Brooklyn, NY 11205'],
#                               'state': 'NY',
#                               'zip_code': '11205'},
#                  'name': 'Dough',
#                  'phone': '+13475337544',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 1675,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/dough-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'brooklyn-bridge-brooklyn',
#                  'categories': [{'alias': 'landmarks',
#                                  'title': 'Landmarks & Historical Buildings'}],
#                  'coordinates': {'latitude': 40.7059677364821,
#                                  'longitude': -73.9966657489186},
#                  'display_phone': '(718) 724-6434',
#                  'distance': 5800.499505361856,
#                  'id': 'mvn2XFJfIPNAlvsy-arzkA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1F5Xl0Qn5DW8nzaelPSwMA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '334 Furman St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['334 Furman St',
#                                                   'Brooklyn, NY 11201'],
#                               'state': 'NY',
#                               'zip_code': '11201'},
#                  'name': 'Brooklyn Bridge',
#                  'phone': '+17187246434',
#                  'rating': 4.5,
#                  'review_count': 1275,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/brooklyn-bridge-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'julianas-pizza-brooklyn-5',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#                  'coordinates': {'latitude': 40.7026153030093,
#                                  'longitude': -73.9934159993549},
#                  'display_phone': '(718) 596-6700',
#                  'distance': 5347.510145414778,
#                  'id': 'ysqgdbSrezXgVwER2kQWKA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7JtwTxhWHf3YS70Ss_CfxA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '19 Old Fulton St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['19 Old Fulton St',
#                                                   'Brooklyn, NY 11201'],
#                               'state': 'NY',
#                               'zip_code': '11201'},
#                  'name': "Juliana's Pizza",
#                  'phone': '+17185966700',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 1873,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/julianas-pizza-brooklyn-5?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'l-and-b-spumoni-gardens-brooklyn',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'italian', 'title': 'Italian'}],
#                  'coordinates': {'latitude': 40.594715,
#                                  'longitude': -73.981316},
#                  'display_phone': '(718) 449-1230',
#                  'distance': 7211.535253880731,
#                  'id': 'vyoA8dxwScuMV_AsTcjQcg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BrTci9PjIwi7V1vkbgkdqg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2725 86th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['2725 86th St',
#                                                   'Brooklyn, NY 11223'],
#                               'state': 'NY',
#                               'zip_code': '11223'},
#                  'name': 'L & B Spumoni Gardens',
#                  'phone': '+17184491230',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 3294,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/l-and-b-spumoni-gardens-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'ample-hills-creamery-brooklyn',
#                  'categories': [{'alias': 'icecream',
#                                  'title': 'Ice Cream & Frozen Yogurt'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 40.6785573557085,
#                                  'longitude': -73.9684746674535},
#                  'display_phone': '(347) 240-3926',
#                  'distance': 2207.475418614401,
#                  'id': 'j051L3Ehkt8bPrO3YnEc1Q',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/r-f1ai-pbgbuya9jULjPdg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '623 Vanderbilt Ave',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['623 Vanderbilt Ave',
#                                                   'Brooklyn, NY 11238'],
#                               'state': 'NY',
#                               'zip_code': '11238'},
#                  'name': 'Ample Hills Creamery',
#                  'phone': '+13472403926',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 1274,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/ample-hills-creamery-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'traif-brooklyn',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'tapasmallplates',
#                                  'title': 'Tapas/Small Plates'}],
#                  'coordinates': {'latitude': 40.710658,
#                                  'longitude': -73.958872},
#                  'display_phone': '(347) 844-9578',
#                  'distance': 5821.202016600415,
#                  'id': 'qLLxS7RwNEjP_jq_KQrPfA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_srdk7UPM4mShxAIqm9aqg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '229 S 4th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['229 S 4th St',
#                                                   'Brooklyn, NY 11211'],
#                               'state': 'NY',
#                               'zip_code': '11211'},
#                  'name': 'Traif',
#                  'phone': '+13478449578',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 1786,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/traif-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'di-fara-pizza-brooklyn',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#                  'coordinates': {'latitude': 40.625093,
#                                  'longitude': -73.961531},
#                  'display_phone': '(718) 258-1367',
#                  'distance': 3772.8949347446114,
#                  'id': 'C8j0q4Ma_S5hBGuAI-aaww',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4dfe9qpe20P-vi3qFjWd4Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1424 Ave J',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['1424 Ave J',
#                                                   'Brooklyn, NY 11230'],
#                               'state': 'NY',
#                               'zip_code': '11230'},
#                  'name': 'Di Fara Pizza',
#                  'phone': '+17182581367',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 3150,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/di-fara-pizza-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'bogota-latin-bistro-brooklyn',
#                  'categories': [{'alias': 'gluten_free',
#                                  'title': 'Gluten-Free'},
#                                 {'alias': 'colombian', 'title': 'Colombian'}],
#                  'coordinates': {'latitude': 40.678165,
#                                  'longitude': -73.978976},
#                  'display_phone': '(718) 230-3805',
#                  'distance': 2368.612604935411,
#                  'id': '96svxj2NIOrba2fBMZAqOQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FgXUCxKbJiHYEWvNvhhZsA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '141 5th Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['141 5th Ave',
#                                                   'Brooklyn, NY 11217'],
#                               'state': 'NY',
#                               'zip_code': '11217'},
#                  'name': 'Bogota Latin Bistro',
#                  'phone': '+17182303805',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 2019,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/bogota-latin-bistro-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'robertas-brooklyn-2',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'italian', 'title': 'Italian'}],
#                  'coordinates': {'latitude': 40.705043534338,
#                                  'longitude': -73.93357123374},
#                  'display_phone': '(718) 417-1118',
#                  'distance': 5892.879230779805,
#                  'id': 'FhXjAc6nKLf414KxYujUHw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xRNPKIfF2Gr02zBiBl3dSA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '261 Moore St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['261 Moore St',
#                                                   'Brooklyn, NY 11206'],
#                               'state': 'NY',
#                               'zip_code': '11206'},
#                  'name': "Roberta's",
#                  'phone': '+17184171118',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 2563,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/robertas-brooklyn-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'grimaldis-brooklyn-4',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#                  'coordinates': {'latitude': 40.7025694629739,
#                                  'longitude': -73.993247611872},
#                  'display_phone': '(718) 858-4300',
#                  'distance': 5337.069251393053,
#                  'id': '2ggi1luerd3Mf_C82JvCYg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-j-vYFV9Yx5dkS1u8-BY1A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1 Front St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['1 Front St',
#                                                   'Brooklyn, NY 11201'],
#                               'state': 'NY',
#                               'zip_code': '11201'},
#                  'name': "Grimaldi's",
#                  'phone': '+17188584300',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 4436,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/grimaldis-brooklyn-4?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'prospect-park-brooklyn',
#                  'categories': [{'alias': 'parks', 'title': 'Parks'}],
#                  'coordinates': {'latitude': 40.66553, 'longitude': -73.974029},
#                  'display_phone': '(718) 965-8951',
#                  'distance': 935.7649540470434,
#                  'id': 'Mn_as8S7-fJjahyn4AF6Pw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-CjfngBhRYx-7ui4uLJLEA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '95 Prospect Park W',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['95 Prospect Park W',
#                                                   'Brooklyn, NY 11215'],
#                               'state': 'NY',
#                               'zip_code': '11215'},
#                  'name': 'Prospect Park',
#                  'phone': '+17189658951',
#                  'rating': 4.5,
#                  'review_count': 537,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/prospect-park-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'brooklyn-botanic-garden-brooklyn-2',
#                  'categories': [{'alias': 'gardens',
#                                  'title': 'Botanical Gardens'}],
#                  'coordinates': {'latitude': 40.669289,
#                                  'longitude': -73.963304},
#                  'display_phone': '(718) 623-7200',
#                  'distance': 1055.0146805331322,
#                  'id': 'IMA18MENFeqdZc5YVh8njg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KPEUV5axO6azB5XPfwgkKA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '990 Washington Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['990 Washington Ave',
#                                                   'Brooklyn, NY 11225'],
#                               'state': 'NY',
#                               'zip_code': '11225'},
#                  'name': 'Brooklyn Botanic Garden',
#                  'phone': '+17186237200',
#                  'rating': 4.5,
#                  'review_count': 707,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/brooklyn-botanic-garden-brooklyn-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'peter-pan-donut-and-pastry-shop-brooklyn-2',
#                  'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#                                 {'alias': 'donuts', 'title': 'Donuts'}],
#                  'coordinates': {'latitude': 40.726086,
#                                  'longitude': -73.952308},
#                  'display_phone': '(718) 389-3676',
#                  'distance': 7599.839698966971,
#                  'id': 'O0xFECgTDf1rbZzW9qUULQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ogfDjUY7VeNhB091V1KiWA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '727 Manhattan Ave',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['727 Manhattan Ave',
#                                                   'Brooklyn, NY 11222'],
#                               'state': 'NY',
#                               'zip_code': '11222'},
#                  'name': 'Peter Pan Donut & Pastry Shop',
#                  'phone': '+17183893676',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 1180,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/peter-pan-donut-and-pastry-shop-brooklyn-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'lucali-brooklyn-3',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#                  'coordinates': {'latitude': 40.6818, 'longitude': -74.00024},
#                  'display_phone': '(718) 858-4086',
#                  'distance': 3773.4483392652696,
#                  'id': 'Q9F2ocrmYuGt1yn3M7MOBw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hedx-J8avyAe6npDPphRkA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '575 Henry St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['575 Henry St',
#                                                   'Brooklyn, NY 11231'],
#                               'state': 'NY',
#                               'zip_code': '11231'},
#                  'name': 'Lucali',
#                  'phone': '+17188584086',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 1252,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/lucali-brooklyn-3?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'pies-n-thighs-brooklyn',
#                  'categories': [{'alias': 'southern', 'title': 'Southern'},
#                                 {'alias': 'bbq', 'title': 'Barbeque'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'}],
#                  'coordinates': {'latitude': 40.711191,
#                                  'longitude': -73.961424},
#                  'display_phone': '(347) 529-6090',
#                  'distance': 5857.233152822104,
#                  'id': 'j9TdOBSQ1LRw8v3hW5fObQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZEox6v_ipIvcrzeRv9mFIA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '166 S 4th St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['166 S 4th St',
#                                                   'Brooklyn, NY 11211'],
#                               'state': 'NY',
#                               'zip_code': '11211'},
#                  'name': 'Pies-n-Thighs',
#                  'phone': '+13475296090',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 2655,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/pies-n-thighs-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'williamsburg-smorgasburg-saturday-brooklyn',
#                  'categories': [{'alias': 'foodstands',
#                                  'title': 'Food Stands'}],
#                  'coordinates': {'latitude': 40.721021,
#                                  'longitude': -73.962177},
#                  'display_phone': '(718) 928-6603',
#                  'distance': 6942.323438503383,
#                  'id': 'gUJ6pHYd_fp2Ypq377P_vA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AfHMTeso1Em1-pKsFDrEtQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '90 Kent Ave',
#                               'address2': '',
#                               'address3': 'East River State Park',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['90 Kent Ave',
#                                                   'East River State Park',
#                                                   'Brooklyn, NY 11211'],
#                               'state': 'NY',
#                               'zip_code': '11211'},
#                  'name': 'Williamsburg Smorgasburg - Saturday',
#                  'phone': '+17189286603',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 1028,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/williamsburg-smorgasburg-saturday-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'cafe-mogador-brooklyn',
#                  'categories': [{'alias': 'moroccan', 'title': 'Moroccan'}],
#                  'coordinates': {'latitude': 40.719747,
#                                  'longitude': -73.959993},
#                  'display_phone': '(718) 486-9222',
#                  'distance': 6815.626576465159,
#                  'id': 'jAaVnUKLITkuhzwXIe0vLQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wgVgXG4CJixF3yliqBlRhw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '133 Wythe Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['133 Wythe Ave',
#                                                   'Brooklyn, NY 11211'],
#                               'state': 'NY',
#                               'zip_code': '11211'},
#                  'name': 'Cafe Mogador',
#                  'phone': '+17184869222',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 1034,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/cafe-mogador-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'brooklyn-bridge-park-brooklyn-3',
#                  'categories': [{'alias': 'parks', 'title': 'Parks'}],
#                  'coordinates': {'latitude': 40.7016262778116,
#                                  'longitude': -73.9972114562988},
#                  'display_phone': '(718) 222-9939',
#                  'distance': 5388.413211499559,
#                  'id': 'riGhXci7Xo-Gp9gtl5IBYA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vtdWyO6PvxhUGqGAzIQvmw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '334 Furman St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['334 Furman St',
#                                                   'Brooklyn, NY 11201'],
#                               'state': 'NY',
#                               'zip_code': '11201'},
#                  'name': 'Brooklyn Bridge Park',
#                  'phone': '+17182229939',
#                  'rating': 4.5,
#                  'review_count': 491,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/brooklyn-bridge-park-brooklyn-3?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'sweet-chick-brooklyn',
#                  'categories': [{'alias': 'southern', 'title': 'Southern'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'}],
#                  'coordinates': {'latitude': 40.718423,
#                                  'longitude': -73.9574279},
#                  'display_phone': '(347) 725-4793',
#                  'distance': 6693.086502351666,
#                  'id': '4KHjnRNvrkKHchEznhlnSA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-B7HnMZQQh1MemYmypaJ0Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '164 Bedford Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['164 Bedford Ave',
#                                                   'Brooklyn, NY 11211'],
#                               'state': 'NY',
#                               'zip_code': '11211'},
#                  'name': 'Sweet Chick',
#                  'phone': '+13477254793',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1753,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/sweet-chick-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'buttermilk-channel-brooklyn',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'}],
#                  'coordinates': {'latitude': 40.675919,
#                                  'longitude': -73.999059},
#                  'display_phone': '(718) 852-8490',
#                  'distance': 3276.6903927534704,
#                  'id': 'rU9cKxAVU4Gd_JhAqp_bTA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/K0r5WsB8cyiyLZSQ64chTw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '524 Court St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['524 Court St',
#                                                   'Brooklyn, NY 11231'],
#                               'state': 'NY',
#                               'zip_code': '11231'},
#                  'name': 'Buttermilk Channel',
#                  'phone': '+17188528490',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1774,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/buttermilk-channel-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'ba-xuyen-brooklyn-2',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#                  'coordinates': {'latitude': 40.64528,
#                                  'longitude': -73.9997099},
#                  'display_phone': '(718) 633-6601',
#                  'distance': 3097.8620446634045,
#                  'id': 'O-zwQQV8AExgdPoJiqjpDg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0ughD3xXQYDcwvuHzUdj3w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4222 8th Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['4222 8th Ave',
#                                                   'Brooklyn, NY 11232'],
#                               'state': 'NY',
#                               'zip_code': '11232'},
#                  'name': 'Ba Xuyen',
#                  'phone': '+17186336601',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 605,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/ba-xuyen-brooklyn-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'fette-sau-brooklyn',
#                  'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'}],
#                  'coordinates': {'latitude': 40.714066,
#                                  'longitude': -73.956327},
#                  'display_phone': '(718) 963-3404',
#                  'distance': 6226.231453026699,
#                  'id': 'mlGfXoxc8cEss8Yms6VrXg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rxzd7I7H1zVm0bWrDBCvKw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '354 Metropolitan Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['354 Metropolitan Ave',
#                                                   'Brooklyn, NY 11211'],
#                               'state': 'NY',
#                               'zip_code': '11211'},
#                  'name': 'Fette Sau',
#                  'phone': '+17189633404',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 2176,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/fette-sau-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'soco-brooklyn',
#                  'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#                                 {'alias': 'bbq', 'title': 'Barbeque'},
#                                 {'alias': 'soulfood', 'title': 'Soul Food'}],
#                  'coordinates': {'latitude': 40.693866,
#                                  'longitude': -73.964535},
#                  'display_phone': '(718) 783-1936',
#                  'distance': 3916.2959114997266,
#                  'id': 'oOsJn3leUnWDfErRWMf81g',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nLKKfPQU7t6wiZ0f-pQFDg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '509 Myrtle Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['509 Myrtle Ave',
#                                                   'Brooklyn, NY 11205'],
#                               'state': 'NY',
#                               'zip_code': '11205'},
#                  'name': 'Soco',
#                  'phone': '+17187831936',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1901,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/soco-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'paulie-gees-brooklyn',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'vegan', 'title': 'Vegan'},
#                                 {'alias': 'italian', 'title': 'Italian'}],
#                  'coordinates': {'latitude': 40.729546,
#                                  'longitude': -73.958568},
#                  'display_phone': '(347) 987-3747',
#                  'distance': 7905.9013040938335,
#                  'id': 'pGr5QuQU7Ur5GHLvXbT8bw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1j39J4NABK_RBtO-l90QNg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '60 Greenpoint Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['60 Greenpoint Ave',
#                                                   'Brooklyn, NY 11222'],
#                               'state': 'NY',
#                               'zip_code': '11222'},
#                  'name': "Paulie Gee's",
#                  'phone': '+13479873747',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 1144,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/paulie-gees-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'hometown-bar-b-que-brooklyn-3',
#                  'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#                                 {'alias': 'smokehouse', 'title': 'Smokehouse'}],
#                  'coordinates': {'latitude': 40.6748965703426,
#                                  'longitude': -74.0160489746129},
#                  'display_phone': '(347) 294-4644',
#                  'distance': 4471.397163740787,
#                  'id': 'Ms3CAGddVbgetiQrpzqxPQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/g9eRsS6m5fAV2u8TZEEaDw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '454 Van Brunt St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['454 Van Brunt St',
#                                                   'Brooklyn, NY 11231'],
#                               'state': 'NY',
#                               'zip_code': '11231'},
#                  'name': 'Hometown Bar-B-Que',
#                  'phone': '+13472944644',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1140,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/hometown-bar-b-que-brooklyn-3?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'champs-diner-brooklyn',
#                  'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#                                 {'alias': 'bakeries', 'title': 'Bakeries'},
#                                 {'alias': 'diners', 'title': 'Diners'}],
#                  'coordinates': {'latitude': 40.7084397372605,
#                                  'longitude': -73.9407808520115},
#                  'display_phone': '(718) 599-2743',
#                  'distance': 5970.631370101759,
#                  'id': 'u_3TLN0u6LyOL01vdjFOug',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6-VLM94qCEEm49uLI39CUA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '197 Meserole St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['197 Meserole St',
#                                                   'Brooklyn, NY 11206'],
#                               'state': 'NY',
#                               'zip_code': '11206'},
#                  'name': 'Champs Diner',
#                  'phone': '+17185992743',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1257,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/champs-diner-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'pates-et-traditions-brooklyn',
#                  'categories': [{'alias': 'french', 'title': 'French'},
#                                 {'alias': 'desserts', 'title': 'Desserts'}],
#                  'coordinates': {'latitude': 40.71485, 'longitude': -73.95466},
#                  'display_phone': '(718) 302-1878',
#                  'distance': 6338.541617259072,
#                  'id': 't-ODuKsmRseJoTEVKQzsdg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OL9u2JZVjKWXxVoYA9jYVw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '52 Havemeyer St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['52 Havemeyer St',
#                                                   'Brooklyn, NY 11211'],
#                               'state': 'NY',
#                               'zip_code': '11211'},
#                  'name': 'Pates Et Traditions',
#                  'phone': '+17183021878',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 795,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/pates-et-traditions-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'ample-hills-creamery-brooklyn-5',
#                  'categories': [{'alias': 'icecream',
#                                  'title': 'Ice Cream & Frozen Yogurt'}],
#                  'coordinates': {'latitude': 40.678907,
#                                  'longitude': -73.987319},
#                  'display_phone': '(347) 725-4061',
#                  'distance': 2798.124535425932,
#                  'id': 'Xv4kqYmtB7svT0r1-ABlZg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EXRIOs_ALcD8hdIsInL1dg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '305 Nevins St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['305 Nevins St',
#                                                   'Brooklyn, NY 11215'],
#                               'state': 'NY',
#                               'zip_code': '11215'},
#                  'name': 'Ample Hills Creamery',
#                  'phone': '+13477254061',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 501,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/ample-hills-creamery-brooklyn-5?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'destefanos-steakhouse-brooklyn',
#                  'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#                  'coordinates': {'latitude': 40.71503, 'longitude': -73.94767},
#                  'display_phone': '(718) 384-2836',
#                  'distance': 6482.6195571275875,
#                  'id': 'hthvpEL7JEbfxfD6iP9axQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FhtZVlFw8xFbUCVfLRZVrg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '89 Conselyea St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['89 Conselyea St',
#                                                   'Brooklyn, NY 11211'],
#                               'state': 'NY',
#                               'zip_code': '11211'},
#                  'name': "DeStefano's Steakhouse",
#                  'phone': '+17183842836',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 723,
#                  'transactions': ['restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/destefanos-steakhouse-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'barboncino-pizza-and-bar-brooklyn-2',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'bars', 'title': 'Bars'},
#                                 {'alias': 'italian', 'title': 'Italian'}],
#                  'coordinates': {'latitude': 40.67209, 'longitude': -73.95731},
#                  'display_phone': '(718) 483-8834',
#                  'distance': 1717.4699108313885,
#                  'id': 'xRiLLXjeM2wOvVTYJH2__A',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/48doX4sxCRLxOl8a6AD35Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '781 Franklin Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['781 Franklin Ave',
#                                                   'Brooklyn, NY 11238'],
#                               'state': 'NY',
#                               'zip_code': '11238'},
#                  'name': 'Barboncino Pizza & Bar',
#                  'phone': '+17184838834',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 855,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/barboncino-pizza-and-bar-brooklyn-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'toms-brooklyn',
#                  'categories': [{'alias': 'diners', 'title': 'Diners'},
#                                 {'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'},
# ...
#                 {'alias': 'the-river-café-brooklyn-3',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'wine_bars', 'title': 'Wine Bars'},
#                                 {'alias': 'venues',
#                                  'title': 'Venues & Event Spaces'}],
#                  'coordinates': {'latitude': 40.70318,
#                                  'longitude': -73.9946499},
#                  'display_phone': '(718) 522-5200',
#                  'distance': 5448.815680469066,
#                  'id': '4XX-zF8h5Lvrr22_tqU6-Q',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hxFmPlmIkQvyNAf02z2r1Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1 Water St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['1 Water St',
#                                                   'Brooklyn, NY 11201'],
#                               'state': 'NY',
#                               'zip_code': '11201'},
#                  'name': 'The River Café',
#                  'phone': '+17185225200',
#                  'price': '$$$$',
#                  'rating': 4.0,
#                  'review_count': 998,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-river-caf%C3%A9-brooklyn-3?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'le-barricou-brooklyn',
#                  'categories': [{'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'french', 'title': 'French'},
#                                 {'alias': 'bars', 'title': 'Bars'}],
#                  'coordinates': {'latitude': 40.71118, 'longitude': -73.95003},
#                  'display_phone': '(718) 782-7372',
#                  'distance': 6019.9259903369875,
#                  'id': 'TIjtmaeUZexPZvcBz73VCw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/h0tBrxjapI_wwIGBzsegEg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '533 Grand St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['533 Grand St',
#                                                   'Brooklyn, NY 11211'],
#                               'state': 'NY',
#                               'zip_code': '11211'},
#                  'name': 'Le Barricou',
#                  'phone': '+17187827372',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1176,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/le-barricou-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'babas-pierogies-brooklyn',
#                  'categories': [{'alias': 'modern_european',
#                                  'title': 'Modern European'},
#                                 {'alias': 'slovakian', 'title': 'Slovakian'}],
#                  'coordinates': {'latitude': 40.67687, 'longitude': -73.98633},
#                  'display_phone': '(718) 222-0777',
#                  'distance': 2559.4098751616507,
#                  'id': 'eIbKiQuExi12NcGeqMzQAw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LpSQQDCxYapJWk065wJjCQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '295 3rd Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['295 3rd Ave',
#                                                   'Brooklyn, NY 11215'],
#                               'state': 'NY',
#                               'zip_code': '11215'},
#                  'name': "Baba's Pierogies",
#                  'phone': '+17182220777',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 330,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/babas-pierogies-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'the-islands-brooklyn-2',
#                  'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#                  'coordinates': {'latitude': 40.6770523794749,
#                                  'longitude': -73.9634169638157},
#                  'display_phone': '(718) 398-3575',
#                  'distance': 2067.7209429211216,
#                  'id': 'KBW0EP-prQBhkqqGJCxmXg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eEQ3bLkWhPSIvJBIpazk2w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '671 Washington Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['671 Washington Ave',
#                                                   'Brooklyn, NY 11238'],
#                               'state': 'NY',
#                               'zip_code': '11238'},
#                  'name': 'The Islands',
#                  'phone': '+17183983575',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 666,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-islands-brooklyn-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'five-leaves-brooklyn-2',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'bars', 'title': 'Bars'}],
#                  'coordinates': {'latitude': 40.72371830945,
#                                  'longitude': -73.95159863632},
#                  'display_phone': '(718) 383-5345',
#                  'distance': 7351.157690970911,
#                  'id': '1Q3oaJahyGRogDWgpo7PIw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pgLmE_Z9iKhI-6oA1RQUJQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '18 Bedford Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['18 Bedford Ave',
#                                                   'Brooklyn, NY 11222'],
#                               'state': 'NY',
#                               'zip_code': '11222'},
#                  'name': 'Five Leaves',
#                  'phone': '+17183835345',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1498,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/five-leaves-brooklyn-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'radegast-hall-and-biergarten-brooklyn',
#                  'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#                                 {'alias': 'german', 'title': 'German'},
#                                 {'alias': 'venues',
#                                  'title': 'Venues & Event Spaces'}],
#                  'coordinates': {'latitude': 40.716641,
#                                  'longitude': -73.961498},
#                  'display_phone': '(718) 963-3973',
#                  'distance': 6460.6352741107685,
#                  'id': 'TOaQzGPAIQWQUIXi4CPnbA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9UaBOas9SDbiYHv-pyxvkA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '113 N 3rd St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['113 N 3rd St',
#                                                   'Brooklyn, NY 11249'],
#                               'state': 'NY',
#                               'zip_code': '11249'},
#                  'name': 'Radegast Hall and Biergarten',
#                  'phone': '+17189633973',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1265,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/radegast-hall-and-biergarten-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'maison-premiere-brooklyn',
#                  'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'bars', 'title': 'Bars'},
#                                 {'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'}],
#                  'coordinates': {'latitude': 40.7142031,
#                                  'longitude': -73.9614855},
#                  'display_phone': '(347) 335-0446',
#                  'distance': 6190.514089633844,
#                  'id': 'O4rYM6YBj90W2u7RhG3Mvg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GVbEC4IjeGa3nMQKSbWYDA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '298 Bedford Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['298 Bedford Ave',
#                                                   'Brooklyn, NY 11249'],
#                               'state': 'NY',
#                               'zip_code': '11249'},
#                  'name': 'Maison Premiere',
#                  'phone': '+13473350446',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 1060,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/maison-premiere-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'sea-brooklyn-2',
#                  'categories': [{'alias': 'thai', 'title': 'Thai'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'}],
#                  'coordinates': {'latitude': 40.71807, 'longitude': -73.960044},
#                  'display_phone': '(718) 384-8850',
#                  'distance': 6628.059337564802,
#                  'id': 'QVWmn5jmy_TPmg0G71Dk5g',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sp88pD_V-MCXPhtTdsyQqQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '114 N 6th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['114 N 6th St',
#                                                   'Brooklyn, NY 11211'],
#                               'state': 'NY',
#                               'zip_code': '11211'},
#                  'name': 'Sea',
#                  'phone': '+17183848850',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 2759,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/sea-brooklyn-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'chuko-brooklyn-2',
#                  'categories': [{'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'},
#                                 {'alias': 'ramen', 'title': 'Ramen'}],
#                  'coordinates': {'latitude': 40.680784,
#                                  'longitude': -73.967455},
#                  'display_phone': '(347) 425-9570',
#                  'distance': 2453.584432581943,
#                  'id': 'eS9mTLlWwu_Ap2ROMQWPxg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AH6y2pp9yS_36BMoqr5dbQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '565 Vanderbilt Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['565 Vanderbilt Ave',
#                                                   'Brooklyn, NY 11238'],
#                               'state': 'NY',
#                               'zip_code': '11238'},
#                  'name': 'Chuko',
#                  'phone': '+13474259570',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1006,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/chuko-brooklyn-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'dun-well-doughnuts-brooklyn',
#                  'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 40.707743,
#                                  'longitude': -73.940202},
#                  'display_phone': '(347) 294-0871',
#                  'distance': 5917.79228889489,
#                  'id': 'yOc5CZ5VxHGqj96RUuZCMA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ib1ENpQOrRG3lXJPJC810Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '222 Montrose Ave',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': ['222 Montrose Ave',
#                                                   'Brooklyn, NY 11206'],
#                               'state': 'NY',
#                               'zip_code': '11206'},
#                  'name': 'Dun-Well Doughnuts',
#                  'phone': '+13472940871',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 784,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/dun-well-doughnuts-brooklyn?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'}],
#  'region': {'center': {'latitude': 40.65871840604184,
#                        'longitude': -73.96751403808594}},
#  'total': 13400}

# %%
# Lists
business_names_list = []
categories_list = []
street_address_list = []
city_list = []
country_list = []
lat_list = []
lon_list = []
ratings_list = []
review_count_list = []
price_ratings = []

# Looping through each business in the call
for businesses in api_call["businesses"]:
    try:
        # Name
        name = businesses["name"]
        # print(f"Successfully found business name: {name}")

        # Category 
        category = businesses["categories"][0]["alias"]
        # print(f"Successfully found category: {category}")

        # Street Address
        street_address = businesses["location"]["address1"]
        # print(f"Successfully found street address: {street_address}")

        # City
        city = businesses["location"]["city"]
        # print(f"Successfully found city: {city}")

        # Country
        country = businesses["location"]["country"]
        # print(f"Successfully found country: {country}")
        
        # Latitude
        lat = businesses["coordinates"]["latitude"]
        # print(f"Successfully found latitude: {lat}")
        
        #Longitude 
        lon = businesses["coordinates"]["longitude"]
        # print(f"Successfully found longitude: {lon}")

        # Price rating
        # NOTE: Some places do not have a price rating (ie. $, $$, $$$)
        price = businesses["price"]
        # print(f"Successfully found price rating: {price}")

        # Ratings
        rating = businesses["rating"]
        # print(f"Successfully found rating: {rating}")

        # Review count
        review_count = businesses["review_count"]
        # print(f"Successfully found review counts: {review_count}")
        
        # Appends
        # Tried putting appends after each section, adding them towards the end made it work 
        # with no error since it passes those without a price rating
        business_names_list.append(name) 
        categories_list.append(category)
        street_address_list.append(street_address)
        city_list.append(city)
        country_list.append(country)
        lat_list.append(lat)
        lon_list.append(lon)
        price_ratings.append(price)
        ratings_list.append(rating)
        review_count_list.append(review_count)
        
        # print("- - - - - - - - - - - - - - - - - - - - - -")
    except Exception:
        pass

# %% [markdown]
# # Yelp DataFrame

# %%
# Dictionary for DataFrame
business_details_dict = ({"Name": business_names_list,
                          "Category": categories_list,
                          "Street": street_address_list,
                          "City": city_list,
                          "Country": country_list,
                          "Latitude": lat_list,
                          "Longitude": lon_list,
                          "Rating": ratings_list,
                          "Review Count": review_count_list,
                          "$": price_ratings})

# Dictionary to DataFrame
yelp_df = pd.DataFrame(business_details_dict)
yelp_df.head()
# Out:
#                     Name  Category              Street      City Country  \
# 0            Peter Luger     steak        178 Broadway  Brooklyn      US
# 1                  Dough    donuts    448 Franklin Ave  Brooklyn      US
# 2        Juliana's Pizza     pizza    19 Old Fulton St  Brooklyn      US
# 3  L & B Spumoni Gardens     pizza        2725 86th St  Brooklyn      US
# 4   Ample Hills Creamery  icecream  623 Vanderbilt Ave  Brooklyn      US
#
#     Latitude  Longitude  Rating  Review Count     $
# 0  40.709945 -73.962478     4.0          5108  $$$$
# 1  40.689070 -73.957078     4.5          1675     $
# 2  40.702615 -73.993416     4.5          1873    $$
# 3  40.594715 -73.981316     4.0          3294     $
# 4  40.678557 -73.968475     4.5          1274    $$

# %% [markdown]
# # Sorting by Review Count

# %%
sorted_df_reviews = yelp_df.sort_values(by=["Review Count"], ascending=False)
sorted_df_reviews
# Out:
#                                    Name          Category  \
# 0                           Peter Luger             steak
# 9                            Grimaldi's             pizza
# 3                 L & B Spumoni Gardens             pizza
# 6                         Di Fara Pizza             pizza
# 41                                  Sea              thai
# 12                        Pies-n-Thighs          southern
# 8                             Roberta's             pizza
# 18                            Fette Sau               bbq
# 7                   Bogota Latin Bistro       gluten_free
# 19                                 Soco             cajun
# 2                       Juliana's Pizza             pizza
# 5                                 Traif       newamerican
# 16                   Buttermilk Channel       newamerican
# 15                          Sweet Chick          southern
# 1                                 Dough            donuts
# 38                          Five Leaves       newamerican
# 32                           Cafe Luluc            french
# 4                  Ample Hills Creamery          icecream
# 39         Radegast Hall and Biergarten              pubs
# 22                         Champs Diner             vegan
# 11                               Lucali             pizza
# 27                                Tom's            diners
# 10        Peter Pan Donut & Pastry Shop          bakeries
# 35                          Le Barricou  breakfast_brunch
# 20                         Paulie Gee's             pizza
# 21                   Hometown Bar-B-Que               bbq
# 29                 The Farm On Adderley       newamerican
# 40                      Maison Premiere           seafood
# 14                         Cafe Mogador          moroccan
# 13  Williamsburg Smorgasburg - Saturday        foodstands
# 42                                Chuko       asianfusion
# 34                       The River Café       newamerican
# 28                             Zenkichi          japanese
# 26               Barboncino Pizza & Bar             pizza
# 33                                 Olea  breakfast_brunch
# 23                  Pates Et Traditions            french
# 43                   Dun-Well Doughnuts            donuts
# 25               DeStefano's Steakhouse             steak
# 37                          The Islands         caribbean
# 17                             Ba Xuyen        vietnamese
# 24                 Ample Hills Creamery          icecream
# 31                        Laojie Hotpot            hotpot
# 30                 L'industrie Pizzeria             pizza
# 36                     Baba's Pierogies   modern_european
#
#                   Street      City Country   Latitude  Longitude  Rating  \
# 0           178 Broadway  Brooklyn      US  40.709945 -73.962478     4.0
# 9             1 Front St  Brooklyn      US  40.702569 -73.993248     3.5
# 3           2725 86th St  Brooklyn      US  40.594715 -73.981316     4.0
# 6             1424 Ave J  Brooklyn      US  40.625093 -73.961531     4.0
# 41          114 N 6th St  Brooklyn      US  40.718070 -73.960044     3.5
# 12          166 S 4th St  Brooklyn      US  40.711191 -73.961424     4.0
# 8           261 Moore St  Brooklyn      US  40.705044 -73.933571     4.0
# 18  354 Metropolitan Ave  Brooklyn      US  40.714066 -73.956327     4.0
# 7            141 5th Ave  Brooklyn      US  40.678165 -73.978976     4.0
# 19        509 Myrtle Ave  Brooklyn      US  40.693866 -73.964535     4.0
# 2       19 Old Fulton St  Brooklyn      US  40.702615 -73.993416     4.5
# 5           229 S 4th St  Brooklyn      US  40.710658 -73.958872     4.5
# 16          524 Court St  Brooklyn      US  40.675919 -73.999059     4.0
# 15       164 Bedford Ave  Brooklyn      US  40.718423 -73.957428     4.0
# 1       448 Franklin Ave  Brooklyn      US  40.689070 -73.957078     4.5
# 38        18 Bedford Ave  Brooklyn      US  40.723718 -73.951599     4.0
# 32          214 Smith St  Brooklyn      US  40.684470 -73.992140     4.0
# 4     623 Vanderbilt Ave  Brooklyn      US  40.678557 -73.968475     4.5
# 39          113 N 3rd St  Brooklyn      US  40.716641 -73.961498     4.0
# 22       197 Meserole St  Brooklyn      US  40.708440 -73.940781     4.0
# 11          575 Henry St  Brooklyn      US  40.681800 -74.000240     4.5
# 27    782 Washington Ave  Brooklyn      US  40.674491 -73.963439     4.0
# 10     727 Manhattan Ave  Brooklyn      US  40.726086 -73.952308     4.5
# 35          533 Grand St  Brooklyn      US  40.711180 -73.950030     4.0
# 20     60 Greenpoint Ave  Brooklyn      US  40.729546 -73.958568     4.5
# 21      454 Van Brunt St  Brooklyn      US  40.674897 -74.016049     4.0
# 29     1108 Cortelyou Rd  Brooklyn      US  40.639650 -73.967540     4.0
# 40       298 Bedford Ave  Brooklyn      US  40.714203 -73.961485     4.0
# 14         133 Wythe Ave  Brooklyn      US  40.719747 -73.959993     4.5
# 13           90 Kent Ave  Brooklyn      US  40.721021 -73.962177     4.5
# 42    565 Vanderbilt Ave  Brooklyn      US  40.680784 -73.967455     4.0
# 34            1 Water St  Brooklyn      US  40.703180 -73.994650     4.0
# 28           77 N 6th St  Brooklyn      US  40.718972 -73.960830     4.0
# 26      781 Franklin Ave  Brooklyn      US  40.672090 -73.957310     4.5
# 33     171 Lafayette Ave  Brooklyn      US  40.687784 -73.970605     4.0
# 23       52 Havemeyer St  Brooklyn      US  40.714850 -73.954660     4.5
# 43      222 Montrose Ave  Brooklyn      US  40.707743 -73.940202     4.0
# 25       89 Conselyea St  Brooklyn      US  40.715030 -73.947670     4.5
# 37    671 Washington Ave  Brooklyn      US  40.677052 -73.963417     4.5
# 17          4222 8th Ave  Brooklyn      US  40.645280 -73.999710     4.5
# 24         305 Nevins St  Brooklyn      US  40.678907 -73.987319     4.5
# 31           811 53rd St  Brooklyn      US  40.638971 -74.004685     4.5
# 30          254 S 2nd St  Brooklyn      US  40.711620 -73.957830     5.0
# 36           295 3rd Ave  Brooklyn      US  40.676870 -73.986330     4.5
#
#     Review Count     $
# 0           5108  $$$$
# 9           4436    $$
# 3           3294     $
# 6           3150    $$
# 41          2759    $$
# 12          2655    $$
# 8           2563    $$
# 18          2176    $$
# 7           2019    $$
# 19          1901    $$
# 2           1873    $$
# 5           1786   $$$
# 16          1774    $$
# 15          1753    $$
# 1           1675     $
# 38          1498    $$
# 32          1276    $$
# 4           1274    $$
# 39          1265    $$
# 22          1257    $$
# 11          1252    $$
# 27          1211    $$
# 10          1180     $
# 35          1176    $$
# 20          1144    $$
# 21          1140    $$
# 29          1100    $$
# 40          1060   $$$
# 14          1034    $$
# 13          1028    $$
# 42          1006    $$
# 34           998  $$$$
# 28           926   $$$
# 26           855    $$
# 33           799    $$
# 23           795    $$
# 43           784     $
# 25           723   $$$
# 37           666    $$
# 17           605     $
# 24           501    $$
# 31           382    $$
# 30           376     $
# 36           330    $$

# %% [markdown]
# # Category Shares

# %%
# Counting up number in each category
biz_categories = yelp_df.groupby("Category").count()
# Resetting the index to Category
biz_categories.reset_index("Category", inplace=True)
categories = biz_categories["Category"]

# Labels for each category to be used in Plotly 
labels = categories

# Values for each category to be used in Plotly
category_count = biz_categories["Name"]
values = category_count
values

# Setting up arguments for Plotly pie chart 
trace = go.Pie(labels=labels, values=values)

py.iplot([trace], filename= "Pie_Chart_Categories")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~nguyenkevint94/82.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Price Comparisons

# %%
# Grouping price ratings ($)
price_groups = yelp_df.groupby("$").count()
price_groups.reset_index("$", inplace=True)

labels = price_groups["$"]
values = price_groups["Name"]

trace = go.Pie(labels=labels, values=values)

py.iplot([trace], filename= "Pie_Chart_Price_Categories")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~nguyenkevint94/84.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Average Review Count vs. Category

# %%
# Grouping categories 
average_reviews = yelp_df.groupby("Category").mean()
average_reviews.reset_index("Category")

# Gathering top 5 categories with the highest number of reviews
top_five = average_reviews.nlargest(10,"Review Count")
top_five.reset_index("Category", inplace=True)
# Category names
categories = top_five["Category"]

# Category review counts
review_count = top_five["Review Count"]

# Setting up the bar chart
trace = go.Bar(
    x=categories,
    y=review_count,
    text=categories,
    marker=dict(
        color="rgb(158, 202, 225)",
        line=dict(
            color="rgb(8, 48,107)",
            width=1.5,
        )
    ),
    opacity=0.6
)

data=[trace]
layout=go.Layout(
    title="Top 10 Categories by Average Review Count",
)

# Bar chart 
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="top-10-categories-by-average-review-count")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~nguyenkevint94/88.embed" height="525px" width="100%"></iframe>
