# %%
# Dependencies
import pandas as pd
import re
import requests
import math 
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from pprint import pprint
from config import api_key, plotly_key
from yelpapi import YelpAPI

# %% [markdown]
# # API Calls

# %%
yelp_api = YelpAPI(api_key)
input_string = input("Search query: ")
api_call = yelp_api.search_query(location=input_string, limit=50)
plotly.tools.set_credentials_file(username='nguyenkevint94', api_key=plotly_key)
# Out:
# Search query: Newport Beach, CA

# %%
# Printing to view results
pprint(api_call)
# Out:
# {'businesses': [{'alias': 'mama-ds-italian-kitchen-newport-beach',
#                  'categories': [{'alias': 'italian', 'title': 'Italian'},
#                                 {'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'salad', 'title': 'Salad'}],
#                  'coordinates': {'latitude': 33.615048,
#                                  'longitude': -117.930145},
#                  'display_phone': '(949) 675-6262',
#                  'distance': 3294.19087163768,
#                  'id': 'u31pxZqQbajByULMCF6bEQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/g7-s-yTJif8AuUYCmr7Img/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3012 Newport Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['3012 Newport Blvd',
#                                                   'Newport Beach, CA 92663'],
#                               'state': 'CA',
#                               'zip_code': '92663'},
#                  'name': "Mama D's Italian Kitchen",
#                  'phone': '+19496756262',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 5143,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mama-ds-italian-kitchen-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'bosscat-kitchen-and-libations-newport-beach-2',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'lounges', 'title': 'Lounges'},
#                                 {'alias': 'southern', 'title': 'Southern'}],
#                  'coordinates': {'latitude': 33.66985, 'longitude': -117.86526},
#                  'display_phone': '(949) 333-0917',
#                  'distance': 5837.43567155215,
#                  'id': 'ObCj8Y3KAdk4bgc8oSxNcA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aanVUnWu9pXoxVVHANZsFA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4647 MacArthur Blvd',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['4647 MacArthur Blvd',
#                                                   'Newport Beach, CA 92660'],
#                               'state': 'CA',
#                               'zip_code': '92660'},
#                  'name': 'Bosscat Kitchen and Libations',
#                  'phone': '+19493330917',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 2900,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/bosscat-kitchen-and-libations-newport-beach-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'sidecar-doughnuts-and-coffee-costa-mesa',
#                  'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 33.6338258939327,
#                                  'longitude': -117.915276896375},
#                  'display_phone': '(949) 873-5424',
#                  'distance': 2048.0120656763083,
#                  'id': '2cVEsZscNVMHrxPeTLUuLg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/b1FEYxuVF5eWLtwbCJ3goA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '270 E 17th St',
#                               'address2': 'Ste 18',
#                               'address3': '',
#                               'city': 'Costa Mesa',
#                               'country': 'US',
#                               'display_address': ['270 E 17th St',
#                                                   'Ste 18',
#                                                   'Costa Mesa, CA 92627'],
#                               'state': 'CA',
#                               'zip_code': '92627'},
#                  'name': 'Sidecar Doughnuts & Coffee',
#                  'phone': '+19498735424',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 2969,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/sidecar-doughnuts-and-coffee-costa-mesa?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'seaside-bakery-newport-beach-2',
#                  'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#                                 {'alias': 'donuts', 'title': 'Donuts'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 33.6085772281767,
#                                  'longitude': -117.928998246789},
#                  'display_phone': '(949) 675-2533',
#                  'distance': 3492.379850108622,
#                  'id': '8vZVscSmZgBasR2_nK0XsQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DM9OxXElhoEd80W6JwHyvA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2108 W Oceanfront',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['2108 W Oceanfront',
#                                                   'Newport Beach, CA 92663'],
#                               'state': 'CA',
#                               'zip_code': '92663'},
#                  'name': 'Seaside Bakery',
#                  'phone': '+19496752533',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 1292,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/seaside-bakery-newport-beach-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'kean-coffee-newport-beach',
#                  'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#                                 {'alias': 'desserts', 'title': 'Desserts'}],
#                  'coordinates': {'latitude': 33.6276462444132,
#                                  'longitude': -117.908383125935},
#                  'display_phone': '(949) 642-5326',
#                  'distance': 1174.983117738499,
#                  'id': 'apJ_gcu0Q8Pz6nYrY9E9dg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oAvC6SeVFqQgv_q_Dj-aeg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2043 Westcliff Dr',
#                               'address2': 'Ste 100',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['2043 Westcliff Dr',
#                                                   'Ste 100',
#                                                   'Newport Beach, CA 92660'],
#                               'state': 'CA',
#                               'zip_code': '92660'},
#                  'name': 'Kean Coffee',
#                  'phone': '+19496425326',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 1269,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/kean-coffee-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'eddie-vs-prime-seafood-newport-beach',
#                  'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'steak', 'title': 'Steakhouses'},
#                                 {'alias': 'lounges', 'title': 'Lounges'}],
#                  'coordinates': {'latitude': 33.6377679489009,
#                                  'longitude': -117.861073981219},
#                  'display_phone': '(949) 720-9925',
#                  'distance': 3592.829332970777,
#                  'id': 'kgR9KrpmqrwJeKmyKnEA0Q',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wk7rt8aRAWOdYEjFMtVS5g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1370 Bison Ave',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['1370 Bison Ave',
#                                                   'Newport Beach, CA 92660'],
#                               'state': 'CA',
#                               'zip_code': '92660'},
#                  'name': "Eddie V's Prime Seafood",
#                  'phone': '+19497209925',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 1366,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/eddie-vs-prime-seafood-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'sol-mexican-cocina-newport-beach',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'bars', 'title': 'Bars'}],
#                  'coordinates': {'latitude': 33.615833677112,
#                                  'longitude': -117.901565396802},
#                  'display_phone': '(949) 675-9800',
#                  'distance': 1057.8839810639213,
#                  'id': 'D_iHwZBxJq1mbXoKt_jgOQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_VyWNnf9VZKrivYxzxl-zw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '251 E Coast Hwy',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['251 E Coast Hwy',
#                                                   'Newport Beach, CA 92660'],
#                               'state': 'CA',
#                               'zip_code': '92660'},
#                  'name': 'SOL Mexican Cocina',
#                  'phone': '+19496759800',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 2071,
#                  'transactions': ['restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/sol-mexican-cocina-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'true-food-kitchen-newport-beach',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'vegetarian', 'title': 'Vegetarian'},
#                                 {'alias': 'vegan', 'title': 'Vegan'}],
#                  'coordinates': {'latitude': 33.61501, 'longitude': -117.87318},
#                  'display_phone': '(949) 644-2400',
#                  'distance': 2382.6795288596854,
#                  'id': 'F6nwKjlJQJMgoCQxCaqpWw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/E5OLQflfjimKlMTjzLgurg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '451 Newport Center Dr',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['451 Newport Center Dr',
#                                                   'Newport Beach, CA 92660'],
#                               'state': 'CA',
#                               'zip_code': '92660'},
#                  'name': 'True Food Kitchen',
#                  'phone': '+19496442400',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 2177,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/true-food-kitchen-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'saigon-beach-restaurant-newport-beach',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'},
#                                 {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#                  'coordinates': {'latitude': 33.6099494,
#                                  'longitude': -117.9289431},
#                  'display_phone': '(949) 612-8067',
#                  'distance': 3429.87667113975,
#                  'id': '967I__2NjKCCLU1MBdj6Ow',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fAv8jxlIXUtic6MQFzEm8Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2233 W Balboa Blvd',
#                               'address2': 'Ste 102',
#                               'address3': None,
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['2233 W Balboa Blvd',
#                                                   'Ste 102',
#                                                   'Newport Beach, CA 92663'],
#                               'state': 'CA',
#                               'zip_code': '92663'},
#                  'name': 'Saigon Beach Restaurant',
#                  'phone': '+19496128067',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 639,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/saigon-beach-restaurant-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'mastros-ocean-club-newport-beach-2',
#                  'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'steak', 'title': 'Steakhouses'},
#                                 {'alias': 'lounges', 'title': 'Lounges'}],
#                  'coordinates': {'latitude': 33.5679180600631,
#                                  'longitude': -117.830675840378},
#                  'display_phone': '(949) 376-6990',
#                  'distance': 8734.871838438476,
#                  'id': 'jmtpj9xs5qLumYIMd2v5lQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AX0y68qvTU8o851Fyt_6sw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '8112 E Coast Hwy',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['8112 E Coast Hwy',
#                                                   'Newport Beach, CA 92657'],
#                               'state': 'CA',
#                               'zip_code': '92657'},
#                  'name': "Mastro's Ocean Club",
#                  'phone': '+19493766990',
#                  'price': '$$$$',
#                  'rating': 4.0,
#                  'review_count': 1955,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mastros-ocean-club-newport-beach-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'san-shi-go-newport-beach',
#                  'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#                                 {'alias': 'japanese', 'title': 'Japanese'}],
#                  'coordinates': {'latitude': 33.602226,
#                                  'longitude': -117.8995113},
#                  'display_phone': '(949) 673-3724',
#                  'distance': 2466.148577704519,
#                  'id': 'bTRmryZ66iCF-aLWf4tqJw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rbCvkvMxSs63yJSCB3Dmlg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '205 Main St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['205 Main St',
#                                                   'Newport Beach, CA 92661'],
#                               'state': 'CA',
#                               'zip_code': '92661'},
#                  'name': 'San Shi Go',
#                  'phone': '+19496733724',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 684,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/san-shi-go-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'sessions-west-coast-deli-newport-beach',
#                  'categories': [{'alias': 'delis', 'title': 'Delis'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'},
#                                 {'alias': 'newamerican',
#                                  'title': 'American (New)'}],
#                  'coordinates': {'latitude': 33.613681,
#                                  'longitude': -117.929849},
#                  'display_phone': '(949) 220-9001',
#                  'distance': 3319.157681604828,
#                  'id': 'd7rzicAmXe_psfkMz9fF5g',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gNdL7u22oby-klDbA7zsVw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2823 Newport Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['2823 Newport Blvd',
#                                                   'Newport Beach, CA 92663'],
#                               'state': 'CA',
#                               'zip_code': '92663'},
#                  'name': 'Sessions West Coast Deli',
#                  'phone': '+19492209001',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 644,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/sessions-west-coast-deli-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'nana-san-newport-beach',
#                  'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#                                 {'alias': 'japanese', 'title': 'Japanese'}],
#                  'coordinates': {'latitude': 33.656696,
#                                  'longitude': -117.864474},
#                  'display_phone': '(949) 474-7373',
#                  'distance': 4656.673699005101,
#                  'id': 'aKimkqryG4rI9kjErH2mrg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/O0gxd38pVvbH7s27lodYoQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3601 Jamboree Rd',
#                               'address2': 'Ste 15B',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['3601 Jamboree Rd',
#                                                   'Ste 15B',
#                                                   'Newport Beach, CA 92660'],
#                               'state': 'CA',
#                               'zip_code': '92660'},
#                  'name': 'Nana San',
#                  'phone': '+19494747373',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 921,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/nana-san-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'flemings-prime-steakhouse-and-wine-bar-newport-beach-newport-beach',
#                  'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#                                 {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#                  'coordinates': {'latitude': 33.6152036396438,
#                                  'longitude': -117.873185003513},
#                  'display_phone': '(949) 720-9633',
#                  'distance': 2371.1035087865935,
#                  'id': 'lVeuMJsNc8OjYOrEnpfR_w',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Sqw8_s3pisLFAO6F_ASvLw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '455 Newport Center Dr',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['455 Newport Center Dr',
#                                                   'Newport Beach, CA 92660'],
#                               'state': 'CA',
#                               'zip_code': '92660'},
#                  'name': 'Flemings Prime Steakhouse & Wine Bar- Newport Beach',
#                  'phone': '+19497209633',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 1587,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/flemings-prime-steakhouse-and-wine-bar-newport-beach-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'pandor-artisan-boulangerie-and-cafe-newport-beach-3',
#                  'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#                                 {'alias': 'cafes', 'title': 'Cafes'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'}],
#                  'coordinates': {'latitude': 33.6291129167186,
#                                  'longitude': -117.906491620122},
#                  'display_phone': '(949) 209-5099',
#                  'distance': 1081.1906671967229,
#                  'id': 'gYGExTTUSfrhaD4XZMiGsA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lZovUJJ86ffl8cPZM1foRA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1126 Irvine Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['1126 Irvine Ave',
#                                                   'Newport Beach, CA 92660'],
#                               'state': 'CA',
#                               'zip_code': '92660'},
#                  'name': 'Pandor Artisan Boulangerie & Cafe',
#                  'phone': '+19492095099',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 835,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/pandor-artisan-boulangerie-and-cafe-newport-beach-3?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'plums-café-and-catering-costa-mesa-2',
#                  'categories': [{'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'newamerican',
#                                  'title': 'American (New)'}],
#                  'coordinates': {'latitude': 33.6311112814576,
#                                  'longitude': -117.913695573807},
#                  'display_phone': '(949) 722-7586',
#                  'distance': 1775.9883569647875,
#                  'id': 'OLJP0yvcF299-l80UwjADg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ad8dmkGwA4V0LP656kfvCg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '369 E 17th St',
#                               'address2': 'Ste 7',
#                               'address3': '',
#                               'city': 'Costa Mesa',
#                               'country': 'US',
#                               'display_address': ['369 E 17th St',
#                                                   'Ste 7',
#                                                   'Costa Mesa, CA 92627'],
#                               'state': 'CA',
#                               'zip_code': '92627'},
#                  'name': 'Plums Café and Catering',
#                  'phone': '+19497227586',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 2340,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/plums-caf%C3%A9-and-catering-costa-mesa-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'susiecakes-newport-beach-2',
#                  'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#                                 {'alias': 'bakeries', 'title': 'Bakeries'}],
#                  'coordinates': {'latitude': 33.62759, 'longitude': -117.90842},
#                  'display_phone': '(949) 646-6881',
#                  'distance': 1160.7282520828885,
#                  'id': 'mGw_YwIMh_9sqRjouNYt5Q',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3yLe_PDqlmwMBuEy8eAH3g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2043 Westcliff Dr',
#                               'address2': 'Ste 104',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['2043 Westcliff Dr',
#                                                   'Ste 104',
#                                                   'Newport Beach, CA 92660'],
#                               'state': 'CA',
#                               'zip_code': '92660'},
#                  'name': 'SusieCakes',
#                  'phone': '+19496466881',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 858,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/susiecakes-newport-beach-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'red-o-newport-beach-3',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#                                 {'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'steak', 'title': 'Steakhouses'}],
#                  'coordinates': {'latitude': 33.6129616,
#                                  'longitude': -117.875378},
#                  'display_phone': '(949) 718-0300',
#                  'distance': 2314.9015371203036,
#                  'id': 'iWIHTz-Pne2ZziLQqETNHA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i8k6nOzRgCpnNQWQMziqNw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '143 Newport Center Dr',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['143 Newport Center Dr',
#                                                   'Newport Beach, CA 92660'],
#                               'state': 'CA',
#                               'zip_code': '92660'},
#                  'name': 'Red O',
#                  'phone': '+19497180300',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 1546,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/red-o-newport-beach-3?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'sprinkles-cupcakes-newport-beach',
#                  'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#                                 {'alias': 'desserts', 'title': 'Desserts'},
#                                 {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#                  'coordinates': {'latitude': 33.6066333,
#                                  'longitude': -117.8746874},
#                  'display_phone': '(949) 760-0003',
#                  'distance': 2831.3858828279454,
#                  'id': 'Y6NqUwGl6Y63K8eAOPFakA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hfklCl8EYVkFn918Qsuocg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '944 Avocado Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['944 Avocado Ave',
#                                                   'Newport Beach, CA 92660'],
#                               'state': 'CA',
#                               'zip_code': '92660'},
#                  'name': 'Sprinkles Cupcakes',
#                  'phone': '+19497600003',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 1850,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/sprinkles-cupcakes-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'hook-and-anchor-newport-beach',
#                  'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'salad', 'title': 'Salad'}],
#                  'coordinates': {'latitude': 33.6166890689239,
#                                  'longitude': -117.930496666667},
#                  'display_phone': '(949) 423-7169',
#                  'distance': 3273.275814732877,
#                  'id': '86Hicsz5D0Tr9SAGSt9asQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/btqRr3GErP7kPBjBPFa1_g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3305 Newport Blvd',
#                               'address2': 'Ste E',
#                               'address3': None,
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['3305 Newport Blvd',
#                                                   'Ste E',
#                                                   'Newport Beach, CA 92663'],
#                               'state': 'CA',
#                               'zip_code': '92663'},
#                  'name': 'Hook & Anchor',
#                  'phone': '+19494237169',
#                  'price': '$$',
#                  'rating': 5.0,
#                  'review_count': 325,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/hook-and-anchor-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'bear-flag-fish-newport-beach-2',
#                  'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'seafoodmarkets',
#                                  'title': 'Seafood Markets'},
#                                 {'alias': 'sushi', 'title': 'Sushi Bars'}],
#                  'coordinates': {'latitude': 33.6179653265936,
#                                  'longitude': -117.928875927595},
#                  'display_phone': '(949) 673-3474',
#                  'distance': 3093.166613047875,
#                  'id': '_oAHk9kKKbgSaEYinI5Ihw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DgPXfhtWP7wkqJ1oiw-UEA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3421 Via Lido',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['3421 Via Lido',
#                                                   'Newport Beach, CA 92663'],
#                               'state': 'CA',
#                               'zip_code': '92663'},
#                  'name': 'Bear Flag Fish',
#                  'phone': '+19496733474',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 970,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/bear-flag-fish-newport-beach-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'cucina-alessa-newport-beach',
#                  'categories': [{'alias': 'italian', 'title': 'Italian'}],
#                  'coordinates': {'latitude': 33.62829, 'longitude': -117.95193},
#                  'display_phone': '(949) 645-2148',
#                  'distance': 5147.533629331295,
#                  'id': 'Zu3VuD72ZZ0epZIb07lG7A',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zzrigO0MOeUZQ5i1M0CTmA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '6700 W Coast Hwy',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['6700 W Coast Hwy',
#                                                   'Newport Beach, CA 92663'],
#                               'state': 'CA',
#                               'zip_code': '92663'},
#                  'name': 'Cucina Alessa',
#                  'phone': '+19496452148',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 793,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/cucina-alessa-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'sol-grill-newport-beach',
#                  'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'steak', 'title': 'Steakhouses'}],
#                  'coordinates': {'latitude': 33.619564,
#                                  'longitude': -117.9213989},
#                  'display_phone': '(949) 287-6797',
#                  'distance': 2378.580636275623,
#                  'id': 'rYl2t-IJhZoIAl4MmuNTGw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7gv2bi43w2DBTBNFw2OHKA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2400 W Coast Hwy',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['2400 W Coast Hwy',
#                                                   'Newport Beach, CA 92663'],
#                               'state': 'CA',
#                               'zip_code': '92663'},
#                  'name': 'Sol Grill',
#                  'phone': '+19492876797',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 522,
#                  'transactions': ['restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/sol-grill-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'eat-chow-costa-mesa',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'}],
#                  'coordinates': {'latitude': 33.64041, 'longitude': -117.91885},
#                  'display_phone': '(949) 650-2469',
#                  'distance': 2750.8764502490435,
#                  'id': 'c1l7ond86j1AXrlAreatTA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W-G3GUOJjvjrzJf8b1Ep8A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1802 Newport Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Costa Mesa',
#                               'country': 'US',
#                               'display_address': ['1802 Newport Blvd',
#                                                   'Costa Mesa, CA 92627'],
#                               'state': 'CA',
#                               'zip_code': '92627'},
#                  'name': 'Eat Chow',
#                  'phone': '+19496502469',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 2114,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/eat-chow-costa-mesa?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'moulin-newport-beach',
#                  'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#                                 {'alias': 'french', 'title': 'French'},
#                                 {'alias': 'cafes', 'title': 'Cafes'}],
#                  'coordinates': {'latitude': 33.6578541,
#                                  'longitude': -117.8665154},
#                  'display_phone': '(949) 474-0920',
#                  'distance': 4642.139036392818,
#                  'id': 'J7c3rL1j4YKAajiXN-PEkg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-U3Cd8G5H92oYaF6Yc8xzg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1000 Bristol St N',
#                               'address2': 'St. 10',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['1000 Bristol St N',
#                                                   'St. 10',
#                                                   'Newport Beach, CA 92660'],
#                               'state': 'CA',
#                               'zip_code': '92660'},
#                  'name': 'Moulin',
#                  'phone': '+19494740920',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 828,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/moulin-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'r-d-kitchen-newport-beach',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'salad', 'title': 'Salad'}],
#                  'coordinates': {'latitude': 33.6174628971887,
#                                  'longitude': -117.874622761447},
#                  'display_phone': '(949) 219-0555',
#                  'distance': 2150.297743228946,
#                  'id': 'x9wrNy_puqy_jQ-wglIoXg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/D61DCWUBAe-fiusaAeeihg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '555 Newport Ctr Dr',
#                               'address2': '',
#                               'address3': 'Fashion Island',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['555 Newport Ctr Dr',
#                                                   'Fashion Island',
#                                                   'Newport Beach, CA 92660'],
#                               'state': 'CA',
#                               'zip_code': '92660'},
#                  'name': 'R+D Kitchen',
#                  'phone': '+19492190555',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1224,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/r-d-kitchen-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'dory-deli-newport-beach',
#                  'categories': [{'alias': 'delis', 'title': 'Delis'},
#                                 {'alias': 'bars', 'title': 'Bars'}],
#                  'coordinates': {'latitude': 33.60868, 'longitude': -117.92892},
#                  'display_phone': '(949) 220-7886',
#                  'distance': 3491.0906069437997,
#                  'id': '2Sciz6if8Z8nj-tLOXpaXw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SSJ9q5awqVPT1pUKmGlPLw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2108 3/4 W Oceanfront',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['2108 3/4 W Oceanfront',
#                                                   'Newport Beach, CA 92663'],
#                               'state': 'CA',
#                               'zip_code': '92663'},
#                  'name': 'Dory Deli',
#                  'phone': '+19492207886',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 669,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/dory-deli-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'sgt-pepperonis-pizza-store-newport-beach-3',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'italian', 'title': 'Italian'},
#                                 {'alias': 'salad', 'title': 'Salad'}],
#                  'coordinates': {'latitude': 33.658821,
#                                  'longitude': -117.87174},
#                  'display_phone': '(949) 852-9500',
#                  'distance': 4463.846385719723,
#                  'id': '-L6KOOnxcjCQwHLtqR0NQQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IMJT9FE-I3TgLXk1UaJlLw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2300 SE Bristol St',
#                               'address2': 'Ste F',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['2300 SE Bristol St',
#                                                   'Ste F',
#                                                   'Newport Beach, CA 92660'],
#                               'state': 'CA',
#                               'zip_code': '92660'},
#                  'name': "Sgt. Pepperoni's Pizza Store",
#                  'phone': '+19498529500',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 660,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/sgt-pepperonis-pizza-store-newport-beach-3?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'tabu-shabu-costa-mesa',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'hotpot', 'title': 'Hot Pot'}],
#                  'coordinates': {'latitude': 33.6322949024825,
#                                  'longitude': -117.914441227913},
#                  'display_phone': '(949) 642-2660',
#                  'distance': 1896.6848784875929,
#                  'id': 'Vf7tOjVKUXEdqi0VmuoLrw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LBgZUDWxgQ5eeMLVt4NBgQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '333 E 17th St',
#                               'address2': 'Unit 19',
#                               'address3': '',
#                               'city': 'Costa Mesa',
#                               'country': 'US',
#                               'display_address': ['333 E 17th St',
#                                                   'Unit 19',
#                                                   'Costa Mesa, CA 92627'],
#                               'state': 'CA',
#                               'zip_code': '92627'},
#                  'name': 'Tabu Shabu',
#                  'phone': '+19496422660',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 1002,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/tabu-shabu-costa-mesa?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
# ...
#                  'id': 'yrg2-w1ZhLNWHny-d4885g',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JXz57M1CdewL6UYmCsKCMA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '703 E Balboa Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['703 E Balboa Blvd',
#                                                   'Newport Beach, CA 92661'],
#                               'state': 'CA',
#                               'zip_code': '92661'},
#                  'name': 'Great Mex',
#                  'phone': '+19496750808',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 495,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/great-mex-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'mendocino-farms-costa-mesa',
#                  'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#                                 {'alias': 'salad', 'title': 'Salad'}],
#                  'coordinates': {'latitude': 33.6298789978027,
#                                  'longitude': -117.909843444824},
#                  'display_phone': '(949) 548-2500',
#                  'distance': 1395.2548577844398,
#                  'id': 'tx7ZjSasmmXdoXg2egfmxg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WmfaL0m_rEfow8rYBX6CGQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '450 E 17th St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Costa Mesa',
#                               'country': 'US',
#                               'display_address': ['450 E 17th St',
#                                                   'Costa Mesa, CA 92627'],
#                               'state': 'CA',
#                               'zip_code': '92627'},
#                  'name': 'Mendocino Farms',
#                  'phone': '+19495482500',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 635,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mendocino-farms-costa-mesa?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'haute-cakes-caffe-newport-beach',
#                  'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'cafes', 'title': 'Cafes'}],
#                  'coordinates': {'latitude': 33.626449911688,
#                                  'longitude': -117.906787124854},
#                  'display_phone': '(949) 642-4114',
#                  'distance': 995.8392914879157,
#                  'id': 'J8JaLsAbFdjTUIxFbfAtLA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8bR7HC4IOl0sWxEGYjqaAA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1807 Westcliff Dr',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['1807 Westcliff Dr',
#                                                   'Newport Beach, CA 92660'],
#                               'state': 'CA',
#                               'zip_code': '92660'},
#                  'name': 'Haute Cakes Caffe',
#                  'phone': '+19496424114',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 915,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/haute-cakes-caffe-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'fly-n-fish-oyster-bar-and-grill-newport-beach',
#                  'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'wine_bars', 'title': 'Wine Bars'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'}],
#                  'coordinates': {'latitude': 33.609884,
#                                  'longitude': -117.929674},
#                  'display_phone': '(949) 673-8400',
#                  'distance': 3477.3555687067196,
#                  'id': 'MZwH5BhkC7CvP0RE-HVO_w',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/U4y6msDdp-k1GCSZB5mR_g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2304 W Oceanfront',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['2304 W Oceanfront',
#                                                   'Newport Beach, CA 92663'],
#                               'state': 'CA',
#                               'zip_code': '92663'},
#                  'name': "Fly 'N' Fish Oyster Bar & Grill",
#                  'phone': '+19496738400',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 677,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/fly-n-fish-oyster-bar-and-grill-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'rusty-pelican-newport-beach',
#                  'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#                  'coordinates': {'latitude': 33.61982, 'longitude': -117.92434},
#                  'display_phone': '(949) 642-3431',
#                  'distance': 2655.082149129575,
#                  'id': 'Cz7h4utoi3jAWemjss5UGw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SRVu1r_0KduEqbaoL9jINQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2735 W Coast Hwy',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['2735 W Coast Hwy',
#                                                   'Newport Beach, CA 92663'],
#                               'state': 'CA',
#                               'zip_code': '92663'},
#                  'name': 'Rusty Pelican',
#                  'phone': '+19496423431',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 1352,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/rusty-pelican-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'lotus-bistro-newport-beach',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#                  'coordinates': {'latitude': 33.624882,
#                                  'longitude': -117.927801},
#                  'display_phone': '(949) 287-6827',
#                  'distance': 2919.3428341572635,
#                  'id': 'UpuAwAmHoR5hcWG4dS-rUw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lEmI7jZDyfnkfdTiQGPBCg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '325 Old Newport Blvd',
#                               'address2': 'Ste 1',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['325 Old Newport Blvd',
#                                                   'Ste 1',
#                                                   'Newport Beach, CA 92663'],
#                               'state': 'CA',
#                               'zip_code': '92663'},
#                  'name': 'Lotus Bistro',
#                  'phone': '+19492876827',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 409,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/lotus-bistro-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'fig-and-olive-newport-beach-newport-beach-3',
#                  'categories': [{'alias': 'mediterranean',
#                                  'title': 'Mediterranean'}],
#                  'coordinates': {'latitude': 33.6132, 'longitude': -117.87481},
#                  'display_phone': '(949) 877-3005',
#                  'distance': 2347.917560135489,
#                  'id': 'lcNgciJjn759BcWk7ua2Kg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2LBgz2pvOqIqW-TJmEGCug/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '151 Newport Center Dr',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['151 Newport Center Dr',
#                                                   'Newport Beach, CA 92660'],
#                               'state': 'CA',
#                               'zip_code': '92660'},
#                  'name': 'Fig & Olive Newport Beach',
#                  'phone': '+19498773005',
#                  'price': '$$$',
#                  'rating': 3.5,
#                  'review_count': 1572,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/fig-and-olive-newport-beach-newport-beach-3?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'panini-kabob-grill-newport-beach',
#                  'categories': [{'alias': 'mediterranean',
#                                  'title': 'Mediterranean'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'persian',
#                                  'title': 'Persian/Iranian'}],
#                  'coordinates': {'latitude': 33.60444, 'longitude': -117.87486},
#                  'display_phone': '(949) 675-8101',
#                  'distance': 2968.7865004159557,
#                  'id': 'rnlkVdX5WW6ygZ1sVeXCjw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0OiilJIdAmIwzG-fLFIxoQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2333 East Coast Hwy',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['2333 East Coast Hwy',
#                                                   'Newport Beach, CA 92625'],
#                               'state': 'CA',
#                               'zip_code': '92625'},
#                  'name': 'Panini Kabob Grill',
#                  'phone': '+19496758101',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 532,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/panini-kabob-grill-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'tupelo-junction-cafe-newport-beach',
#                  'categories': [{'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'}],
#                  'coordinates': {'latitude': 33.61381, 'longitude': -117.92832},
#                  'display_phone': '(949) 877-0280',
#                  'distance': 3179.864410966315,
#                  'id': '7miVY8F7YLS8H23OJzefTQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IwZHCoYV-Jg8iqkviajtfw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '508 29th St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['508 29th St',
#                                                   'Newport Beach, CA 92663'],
#                               'state': 'CA',
#                               'zip_code': '92663'},
#                  'name': 'Tupelo Junction Cafe',
#                  'phone': '+19498770280',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 232,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/tupelo-junction-cafe-newport-beach?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'cafe-gratitude-newport-beach-newport-beach-7',
#                  'categories': [{'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'}],
#                  'coordinates': {'latitude': 33.6257, 'longitude': -117.9057},
#                  'display_phone': '(949) 386-8100',
#                  'distance': 891.2827460692043,
#                  'id': 'JuSMWP9Z7B2CIoMR6iChgg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wUaHhr2GIfgL6H9C3_Te8Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1617 Westcliff Dr',
#                               'address2': 'Ste 112',
#                               'address3': '',
#                               'city': 'Newport Beach',
#                               'country': 'US',
#                               'display_address': ['1617 Westcliff Dr',
#                                                   'Ste 112',
#                                                   'Newport Beach, CA 92260'],
#                               'state': 'CA',
#                               'zip_code': '92260'},
#                  'name': 'Cafe Gratitude - Newport Beach',
#                  'phone': '+19493868100',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 742,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/cafe-gratitude-newport-beach-newport-beach-7?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'}],
#  'region': {'center': {'latitude': 33.62429707718154,
#                        'longitude': -117.89634704589844}},
#  'total': 6800}

# %%
# Lists
business_names_list = []
categories_list = []
street_address_list = []
city_list = []
country_list = []
ratings_list = []
review_count_list = []
price_ratings = []

# Looping through each business in the call
for businesses in api_call["businesses"]:
    try:
        # Name
        name = businesses["name"]
        business_names_list.append(name)
        print(f"Successfully added business name: {name}")

        # Category 
        category = businesses["categories"][0]["alias"]
        categories_list.append(category)
        print(f"Successfully added category: {category}")

        # Street Address
        street_address = businesses["location"]["address1"]
        street_address_list.append(street_address)
        print(f"Successfully added street address: {street_address}")

        # City
        city = businesses["location"]["city"]
        city_list.append(city)
        print(f"Successfully added city: {city}")

        # Country
        country = businesses["location"]["country"]
        country_list.append(country)
        print(f"Successfully added country: {country}")

        # Price rating 
        price = businesses["price"]
        price_ratings.append(price)
        print(f"Successfully added price rating: {price}")

        # Ratings
        rating = businesses["rating"]
        ratings_list.append(rating)
        print(f"Successfully added rating: {rating}")

        # Review count
        review_count = businesses["review_count"]
        review_count_list.append(review_count)
        print(f"Successfully added review counts: {review_count}")
        print("- - - - - - - - - - - - - - - - - - - - - -")
    except Exception:
        pass
# Out:
# Successfully added business name: Mama D's Italian Kitchen
# Successfully added category: italian
# Successfully added street address: 3012 Newport Blvd
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.5
# Successfully added review counts: 5143
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Bosscat Kitchen and Libations
# Successfully added category: newamerican
# Successfully added street address: 4647 MacArthur Blvd
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.5
# Successfully added review counts: 2900
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Sidecar Doughnuts & Coffee
# Successfully added category: donuts
# Successfully added street address: 270 E 17th St
# Successfully added city: Costa Mesa
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.5
# Successfully added review counts: 2969
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Seaside Bakery
# Successfully added category: bakeries
# Successfully added street address: 2108 W Oceanfront
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $
# Successfully added rating: 4.5
# Successfully added review counts: 1292
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Kean Coffee
# Successfully added category: coffee
# Successfully added street address: 2043 Westcliff Dr
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $
# Successfully added rating: 4.5
# Successfully added review counts: 1269
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Eddie V's Prime Seafood
# Successfully added category: seafood
# Successfully added street address: 1370 Bison Ave
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$$
# Successfully added rating: 4.5
# Successfully added review counts: 1366
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: SOL Mexican Cocina
# Successfully added category: mexican
# Successfully added street address: 251 E Coast Hwy
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.0
# Successfully added review counts: 2071
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: True Food Kitchen
# Successfully added category: newamerican
# Successfully added street address: 451 Newport Center Dr
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.0
# Successfully added review counts: 2177
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Saigon Beach Restaurant
# Successfully added category: vietnamese
# Successfully added street address: 2233 W Balboa Blvd
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $
# Successfully added rating: 4.5
# Successfully added review counts: 639
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Mastro's Ocean Club
# Successfully added category: seafood
# Successfully added street address: 8112 E Coast Hwy
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$$$
# Successfully added rating: 4.0
# Successfully added review counts: 1955
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: San Shi Go
# Successfully added category: sushi
# Successfully added street address: 205 Main St
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$$
# Successfully added rating: 4.5
# Successfully added review counts: 684
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Sessions West Coast Deli
# Successfully added category: delis
# Successfully added street address: 2823 Newport Blvd
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.5
# Successfully added review counts: 644
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Nana San
# Successfully added category: sushi
# Successfully added street address: 3601 Jamboree Rd
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$$
# Successfully added rating: 4.5
# Successfully added review counts: 921
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Flemings Prime Steakhouse & Wine Bar- Newport Beach
# Successfully added category: steak
# Successfully added street address: 455 Newport Center Dr
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$$
# Successfully added rating: 4.0
# Successfully added review counts: 1587
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Pandor Artisan Boulangerie & Cafe
# Successfully added category: bakeries
# Successfully added street address: 1126 Irvine Ave
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.5
# Successfully added review counts: 835
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Plums Café and Catering
# Successfully added category: breakfast_brunch
# Successfully added street address: 369 E 17th St
# Successfully added city: Costa Mesa
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.0
# Successfully added review counts: 2340
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: SusieCakes
# Successfully added category: desserts
# Successfully added street address: 2043 Westcliff Dr
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.0
# Successfully added review counts: 858
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Red O
# Successfully added category: mexican
# Successfully added street address: 143 Newport Center Dr
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$$
# Successfully added rating: 4.0
# Successfully added review counts: 1546
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Sprinkles Cupcakes
# Successfully added category: bakeries
# Successfully added street address: 944 Avocado Ave
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 3.5
# Successfully added review counts: 1850
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Hook & Anchor
# Successfully added category: seafood
# Successfully added street address: 3305 Newport Blvd
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 5.0
# Successfully added review counts: 325
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Bear Flag Fish
# Successfully added category: seafood
# Successfully added street address: 3421 Via Lido
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.0
# Successfully added review counts: 970
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Cucina Alessa
# Successfully added category: italian
# Successfully added street address: 6700 W Coast Hwy
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.0
# Successfully added review counts: 793
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Sol Grill
# Successfully added category: seafood
# Successfully added street address: 2400 W Coast Hwy
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.5
# Successfully added review counts: 522
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Eat Chow
# Successfully added category: newamerican
# Successfully added street address: 1802 Newport Blvd
# Successfully added city: Costa Mesa
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.0
# Successfully added review counts: 2114
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Moulin
# Successfully added category: bakeries
# Successfully added street address: 1000 Bristol St N
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.0
# Successfully added review counts: 828
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: R+D Kitchen
# Successfully added category: newamerican
# Successfully added street address: 555 Newport Ctr Dr
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.0
# Successfully added review counts: 1224
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Dory Deli
# Successfully added category: delis
# Successfully added street address: 2108 3/4 W Oceanfront
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.5
# Successfully added review counts: 669
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Sgt. Pepperoni's Pizza Store
# Successfully added category: pizza
# Successfully added street address: 2300 SE Bristol St
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.5
# Successfully added review counts: 660
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Tabu Shabu
# Successfully added category: japanese
# Successfully added street address: 333 E 17th St
# Successfully added city: Costa Mesa
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.5
# Successfully added review counts: 1002
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Eat Chow
# Successfully added category: newamerican
# Successfully added street address: 211 62nd St
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.0
# Successfully added review counts: 671
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: The Winery Restaurant & Wine Bar
# Successfully added category: wine_bars
# Successfully added street address: 3131 W Coast Hwy
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$$
# Successfully added rating: 4.5
# Successfully added review counts: 645
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Vibe Organic Kitchen & Juice
# Successfully added category: juicebars
# Successfully added street address: 1000 Bristol St N
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.5
# Successfully added review counts: 423
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Ten Asian Bistro
# Successfully added category: asianfusion
# Successfully added street address: 4647 MacArthur Blvd
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.0
# Successfully added review counts: 952
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Bluewater Grill
# Successfully added category: seafood
# Successfully added street address: 630 Lido Park Dr
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.0
# Successfully added review counts: 1131
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: C'est Si Bon Bakery
# Successfully added category: bakeries
# Successfully added street address: 149 Riverside Ave
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $
# Successfully added rating: 4.0
# Successfully added review counts: 612
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Gulfstream
# Successfully added category: newamerican
# Successfully added street address: 850 Avocado Ave
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$$
# Successfully added rating: 4.0
# Successfully added review counts: 1145
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Bear Flag Fish
# Successfully added category: seafoodmarkets
# Successfully added street address: 7972 Pacific Coast Hwy
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.0
# Successfully added review counts: 843
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Alta Coffee
# Successfully added category: coffee
# Successfully added street address: 506 31st St
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $
# Successfully added rating: 4.0
# Successfully added review counts: 935
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: The Cannery Restaurant
# Successfully added category: seafood
# Successfully added street address: 3010 Lafayette Rd
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$$
# Successfully added rating: 3.5
# Successfully added review counts: 1278
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Tommy Bahama Restaurant | Bar | Store - Newport Beach
# Successfully added category: hawaiian
# Successfully added street address: 854 Avocado Ave
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.0
# Successfully added review counts: 749
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Great Mex
# Successfully added category: mexican
# Successfully added street address: 703 E Balboa Blvd
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $
# Successfully added rating: 4.5
# Successfully added review counts: 495
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Mendocino Farms
# Successfully added category: sandwiches
# Successfully added street address: 450 E 17th St
# Successfully added city: Costa Mesa
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.5
# Successfully added review counts: 635
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Haute Cakes Caffe
# Successfully added category: bakeries
# Successfully added street address: 1807 Westcliff Dr
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.0
# Successfully added review counts: 915
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Fly 'N' Fish Oyster Bar & Grill
# Successfully added category: seafood
# Successfully added street address: 2304 W Oceanfront
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.0
# Successfully added review counts: 677
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Rusty Pelican
# Successfully added category: seafood
# Successfully added street address: 2735 W Coast Hwy
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 3.5
# Successfully added review counts: 1352
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Lotus Bistro
# Successfully added category: vietnamese
# Successfully added street address: 325 Old Newport Blvd
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $
# Successfully added rating: 4.5
# Successfully added review counts: 409
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Fig & Olive Newport Beach
# Successfully added category: mediterranean
# Successfully added street address: 151 Newport Center Dr
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$$
# Successfully added rating: 3.5
# Successfully added review counts: 1572
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Panini Kabob Grill
# Successfully added category: mediterranean
# Successfully added street address: 2333 East Coast Hwy
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.0
# Successfully added review counts: 532
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Tupelo Junction Cafe
# Successfully added category: tradamerican
# Successfully added street address: 508 29th St
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.5
# Successfully added review counts: 232
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully added business name: Cafe Gratitude - Newport Beach
# Successfully added category: breakfast_brunch
# Successfully added street address: 1617 Westcliff Dr
# Successfully added city: Newport Beach
# Successfully added country: US
# Successfully added price rating: $$
# Successfully added rating: 4.0
# Successfully added review counts: 742
# - - - - - - - - - - - - - - - - - - - - - -

# %%
# Dictionary for DataFrame
business_details_dict = ({"Name": business_names_list,
                          "Category": categories_list,
                          "Street": street_address_list,
                          "City": city_list,
                          "Country": country_list,
                          "Rating": ratings_list,
                          "Review Count": review_count_list,
                          "$": price_ratings})

# Dictionary to DataFrame
yelp_df = pd.DataFrame(business_details_dict)
yelp_df.head(50)
# Out:
#                                                  Name          Category  \
# 0                            Mama D's Italian Kitchen           italian
# 1                       Bosscat Kitchen and Libations       newamerican
# 2                          Sidecar Doughnuts & Coffee            donuts
# 3                                      Seaside Bakery          bakeries
# 4                                         Kean Coffee            coffee
# 5                             Eddie V's Prime Seafood           seafood
# 6                                  SOL Mexican Cocina           mexican
# 7                                   True Food Kitchen       newamerican
# 8                             Saigon Beach Restaurant        vietnamese
# 9                                 Mastro's Ocean Club           seafood
# 10                                         San Shi Go             sushi
# 11                           Sessions West Coast Deli             delis
# 12                                           Nana San             sushi
# 13  Flemings Prime Steakhouse & Wine Bar- Newport ...             steak
# 14                  Pandor Artisan Boulangerie & Cafe          bakeries
# 15                            Plums Café and Catering  breakfast_brunch
# 16                                         SusieCakes          desserts
# 17                                              Red O           mexican
# 18                                 Sprinkles Cupcakes          bakeries
# 19                                      Hook & Anchor           seafood
# 20                                     Bear Flag Fish           seafood
# 21                                      Cucina Alessa           italian
# 22                                          Sol Grill           seafood
# 23                                           Eat Chow       newamerican
# 24                                             Moulin          bakeries
# 25                                        R+D Kitchen       newamerican
# 26                                          Dory Deli             delis
# 27                       Sgt. Pepperoni's Pizza Store             pizza
# 28                                         Tabu Shabu          japanese
# 29                                           Eat Chow       newamerican
# 30                   The Winery Restaurant & Wine Bar         wine_bars
# 31                       Vibe Organic Kitchen & Juice         juicebars
# 32                                   Ten Asian Bistro       asianfusion
# 33                                    Bluewater Grill           seafood
# 34                                C'est Si Bon Bakery          bakeries
# 35                                         Gulfstream       newamerican
# 36                                     Bear Flag Fish    seafoodmarkets
# 37                                        Alta Coffee            coffee
# 38                             The Cannery Restaurant           seafood
# 39  Tommy Bahama Restaurant | Bar | Store - Newpor...          hawaiian
# 40                                          Great Mex           mexican
# 41                                    Mendocino Farms        sandwiches
# 42                                  Haute Cakes Caffe          bakeries
# 43                    Fly 'N' Fish Oyster Bar & Grill           seafood
# 44                                      Rusty Pelican           seafood
# 45                                       Lotus Bistro        vietnamese
# 46                          Fig & Olive Newport Beach     mediterranean
# 47                                 Panini Kabob Grill     mediterranean
# 48                               Tupelo Junction Cafe      tradamerican
# 49                     Cafe Gratitude - Newport Beach  breakfast_brunch
#
#                     Street           City Country  Rating  Review Count     $
# 0        3012 Newport Blvd  Newport Beach      US     4.5          5143    $$
# 1      4647 MacArthur Blvd  Newport Beach      US     4.5          2900    $$
# 2            270 E 17th St     Costa Mesa      US     4.5          2969    $$
# 3        2108 W Oceanfront  Newport Beach      US     4.5          1292     $
# 4        2043 Westcliff Dr  Newport Beach      US     4.5          1269     $
# 5           1370 Bison Ave  Newport Beach      US     4.5          1366   $$$
# 6          251 E Coast Hwy  Newport Beach      US     4.0          2071    $$
# 7    451 Newport Center Dr  Newport Beach      US     4.0          2177    $$
# 8       2233 W Balboa Blvd  Newport Beach      US     4.5           639     $
# 9         8112 E Coast Hwy  Newport Beach      US     4.0          1955  $$$$
# 10             205 Main St  Newport Beach      US     4.5           684   $$$
# 11       2823 Newport Blvd  Newport Beach      US     4.5           644    $$
# 12        3601 Jamboree Rd  Newport Beach      US     4.5           921   $$$
# 13   455 Newport Center Dr  Newport Beach      US     4.0          1587   $$$
# 14         1126 Irvine Ave  Newport Beach      US     4.5           835    $$
# 15           369 E 17th St     Costa Mesa      US     4.0          2340    $$
# 16       2043 Westcliff Dr  Newport Beach      US     4.0           858    $$
# 17   143 Newport Center Dr  Newport Beach      US     4.0          1546   $$$
# 18         944 Avocado Ave  Newport Beach      US     3.5          1850    $$
# 19       3305 Newport Blvd  Newport Beach      US     5.0           325    $$
# 20           3421 Via Lido  Newport Beach      US     4.0           970    $$
# 21        6700 W Coast Hwy  Newport Beach      US     4.0           793    $$
# 22        2400 W Coast Hwy  Newport Beach      US     4.5           522    $$
# 23       1802 Newport Blvd     Costa Mesa      US     4.0          2114    $$
# 24       1000 Bristol St N  Newport Beach      US     4.0           828    $$
# 25      555 Newport Ctr Dr  Newport Beach      US     4.0          1224    $$
# 26   2108 3/4 W Oceanfront  Newport Beach      US     4.5           669    $$
# 27      2300 SE Bristol St  Newport Beach      US     4.5           660    $$
# 28           333 E 17th St     Costa Mesa      US     4.5          1002    $$
# 29             211 62nd St  Newport Beach      US     4.0           671    $$
# 30        3131 W Coast Hwy  Newport Beach      US     4.5           645   $$$
# 31       1000 Bristol St N  Newport Beach      US     4.5           423    $$
# 32     4647 MacArthur Blvd  Newport Beach      US     4.0           952    $$
# 33        630 Lido Park Dr  Newport Beach      US     4.0          1131    $$
# 34       149 Riverside Ave  Newport Beach      US     4.0           612     $
# 35         850 Avocado Ave  Newport Beach      US     4.0          1145   $$$
# 36  7972 Pacific Coast Hwy  Newport Beach      US     4.0           843    $$
# 37             506 31st St  Newport Beach      US     4.0           935     $
# 38       3010 Lafayette Rd  Newport Beach      US     3.5          1278   $$$
# 39         854 Avocado Ave  Newport Beach      US     4.0           749    $$
# 40       703 E Balboa Blvd  Newport Beach      US     4.5           495     $
# 41           450 E 17th St     Costa Mesa      US     4.5           635    $$
# 42       1807 Westcliff Dr  Newport Beach      US     4.0           915    $$
# 43       2304 W Oceanfront  Newport Beach      US     4.0           677    $$
# 44        2735 W Coast Hwy  Newport Beach      US     3.5          1352    $$
# 45    325 Old Newport Blvd  Newport Beach      US     4.5           409     $
# 46   151 Newport Center Dr  Newport Beach      US     3.5          1572   $$$
# 47     2333 East Coast Hwy  Newport Beach      US     4.0           532    $$
# 48             508 29th St  Newport Beach      US     4.5           232    $$
# 49       1617 Westcliff Dr  Newport Beach      US     4.0           742    $$

# %% [markdown]
# # Category Shares

# %%
# Counting up number in each category
biz_categories = yelp_df.groupby("Category").count()
# Resetting the index to Category
biz_categories.reset_index("Category", inplace=True)
categories = biz_categories["Category"]

# Labels for each category to be used in Plotly 
labels = categories

# Values for each category to be used in Plotly
category_count = biz_categories["Name"]
values = category_count
values

# Setting up arguments for Plotly pie chart 
trace = go.Pie(labels=labels, values=values)

py.iplot([trace], filename= "Pie_Chart")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~nguyenkevint94/68.embed" height="525px" width="100%"></iframe>
