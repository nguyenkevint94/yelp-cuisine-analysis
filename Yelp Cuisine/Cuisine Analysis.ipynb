# %%
# Dependencies
import pandas as pd
import re
import requests
import math 
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from pprint import pprint
from config import api_key, plotly_key
from yelpapi import YelpAPI

# %% [markdown]
# # API Calls

# %%
# API call to Yelp API
yelp_api = YelpAPI(api_key)
# Input string for location search
input_string = input("Search query: ")
api_call = yelp_api.search_query(location=input_string, limit=50)

# API Call to Plotly 
plotly.tools.set_credentials_file(username='nguyenkevint94', api_key=plotly_key)
# Out:
# Search query: San Francisco

# %%
# Printing to view results
pprint(api_call)
# Out:
# {'businesses': [{'alias': 'bi-rite-creamery-san-francisco',
#                  'categories': [{'alias': 'icecream',
#                                  'title': 'Ice Cream & Frozen Yogurt'},
#                                 {'alias': 'bakeries', 'title': 'Bakeries'}],
#                  'coordinates': {'latitude': 37.7615877,
#                                  'longitude': -122.4257548},
#                  'display_phone': '(415) 626-5600',
#                  'distance': 944.5063435745504,
#                  'id': 'wGl_DyNxSv8KUtYgiuLhmA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tLwFRwoq7jOTDBJHc6b5-w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3692 18th St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['3692 18th St',
#                                                   'San Francisco, CA 94110'],
#                               'state': 'CA',
#                               'zip_code': '94110'},
#                  'name': 'Bi-Rite Creamery',
#                  'phone': '+14156265600',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 9419,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/bi-rite-creamery-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'brendas-french-soul-food-san-francisco',
#                  'categories': [{'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'french', 'title': 'French'},
#                                 {'alias': 'soulfood', 'title': 'Soul Food'}],
#                  'coordinates': {'latitude': 37.7829016035273,
#                                  'longitude': -122.419043442957},
#                  'display_phone': '(415) 345-8100',
#                  'distance': 2885.38913097158,
#                  'id': 'lJAGnYzku5zSaLnQ_T6_GQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mEzEYZ1lIM6mYfbKgHwCjw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '652 Polk St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['652 Polk St',
#                                                   'San Francisco, CA 94102'],
#                               'state': 'CA',
#                               'zip_code': '94102'},
#                  'name': "Brenda's French Soul Food",
#                  'phone': '+14153458100',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 10098,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/brendas-french-soul-food-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'gary-danko-san-francisco',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'french', 'title': 'French'},
#                                 {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#                  'coordinates': {'latitude': 37.80587, 'longitude': -122.42058},
#                  'display_phone': '(415) 749-2060',
#                  'distance': 5191.341803207417,
#                  'id': 'WavvLdfdP6g8aZTtbBQHTw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CPc91bGzKBe95aM5edjhhQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '800 N Point St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['800 N Point St',
#                                                   'San Francisco, CA 94109'],
#                               'state': 'CA',
#                               'zip_code': '94109'},
#                  'name': 'Gary Danko',
#                  'phone': '+14157492060',
#                  'price': '$$$$',
#                  'rating': 4.5,
#                  'review_count': 5267,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/gary-danko-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'tartine-bakery-and-cafe-san-francisco',
#                  'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#                                 {'alias': 'cafes', 'title': 'Cafes'},
#                                 {'alias': 'desserts', 'title': 'Desserts'}],
#                  'coordinates': {'latitude': 37.7614250022004,
#                                  'longitude': -122.424051321456},
#                  'display_phone': '(415) 487-2600',
#                  'distance': 1091.249585562033,
#                  'id': 'ri7UUYmx21AgSpRsf4-9QA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ctsqUNzbfDH5HsDI61m2fw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '600 Guerrero St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['600 Guerrero St',
#                                                   'San Francisco, CA 94110'],
#                               'state': 'CA',
#                               'zip_code': '94110'},
#                  'name': 'Tartine Bakery & Cafe',
#                  'phone': '+14154872600',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 7496,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/tartine-bakery-and-cafe-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'mitchells-ice-cream-san-francisco',
#                  'categories': [{'alias': 'icecream',
#                                  'title': 'Ice Cream & Frozen Yogurt'},
#                                 {'alias': 'customcakes',
#                                  'title': 'Custom Cakes'}],
#                  'coordinates': {'latitude': 37.7442315,
#                                  'longitude': -122.422816},
#                  'display_phone': '(415) 648-2300',
#                  'distance': 2207.086160001414,
#                  'id': '76smcUUGRvq3k1MVPUXbnA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ttfrmolywd0rLpcYJmf7Uw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '688 San Jose Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['688 San Jose Ave',
#                                                   'San Francisco, CA 94110'],
#                               'state': 'CA',
#                               'zip_code': '94110'},
#                  'name': "Mitchell's Ice Cream",
#                  'phone': '+14156482300',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 3763,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mitchells-ice-cream-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'hog-island-oyster-co-san-francisco',
#                  'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'seafoodmarkets',
#                                  'title': 'Seafood Markets'},
#                                 {'alias': 'raw_food',
#                                  'title': 'Live/Raw Food'}],
#                  'coordinates': {'latitude': 37.795831,
#                                  'longitude': -122.393303},
#                  'display_phone': '(415) 391-7117',
#                  'distance': 5428.15670676801,
#                  'id': 'Xg-FyjVKAN70LO4u4Z1ozg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4avfA7HWOW_Bl0J_8J60rg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1 Ferry Bldg',
#                               'address2': '',
#                               'address3': 'Shop 11',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['1 Ferry Bldg',
#                                                   'Shop 11',
#                                                   'San Francisco, CA 94111'],
#                               'state': 'CA',
#                               'zip_code': '94111'},
#                  'name': 'Hog Island Oyster Co',
#                  'phone': '+14153917117',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 5468,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/hog-island-oyster-co-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'house-of-prime-rib-san-francisco',
#                  'categories': [{'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'},
#                                 {'alias': 'steak', 'title': 'Steakhouses'},
#                                 {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#                  'coordinates': {'latitude': 37.79338, 'longitude': -122.4225},
#                  'display_phone': '(415) 885-4605',
#                  'distance': 3819.642257655711,
#                  'id': 'oT08T3Vpn1I7jDmrBBRMTw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HLrjaMoAgYSac0vx71YpCA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1906 Van Ness Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['1906 Van Ness Ave',
#                                                   'San Francisco, CA 94109'],
#                               'state': 'CA',
#                               'zip_code': '94109'},
#                  'name': 'House of Prime Rib',
#                  'phone': '+14158854605',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 6660,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/house-of-prime-rib-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'burma-superstar-san-francisco-2',
#                  'categories': [{'alias': 'burmese', 'title': 'Burmese'}],
#                  'coordinates': {'latitude': 37.782787322998,
#                                  'longitude': -122.462539672852},
#                  'display_phone': '(415) 387-2147',
#                  'distance': 3346.3513929682595,
#                  'id': 'eYXwVR4mMAjzkJnm5wneHQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UaR8ZJlXHHWO3t-47tp0jg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '309 Clement St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['309 Clement St',
#                                                   'San Francisco, CA 94118'],
#                               'state': 'CA',
#                               'zip_code': '94118'},
#                  'name': 'Burma Superstar',
#                  'phone': '+14153872147',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 6406,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/burma-superstar-san-francisco-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'the-house-san-francisco',
#                  'categories': [{'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 37.7986203,
#                                  'longitude': -122.4070251},
#                  'display_phone': '(415) 986-8612',
#                  'distance': 4911.928931733509,
#                  'id': 'ZoZjbOYR-apY8XvommlNUA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/K48sSeIuHURatMBrSTfOTg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1230 Grant Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['1230 Grant Ave',
#                                                   'San Francisco, CA 94133'],
#                               'state': 'CA',
#                               'zip_code': '94133'},
#                  'name': 'The House',
#                  'phone': '+14159868612',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 4473,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-house-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'kokkari-estiatorio-san-francisco',
#                  'categories': [{'alias': 'greek', 'title': 'Greek'},
#                                 {'alias': 'mediterranean',
#                                  'title': 'Mediterranean'}],
#                  'coordinates': {'latitude': 37.796996,
#                                  'longitude': -122.399661},
#                  'display_phone': '(415) 981-0983',
#                  'distance': 5153.879756630951,
#                  'id': 'PsY5DMHxa5iNX_nX0T-qPA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZVDRZBLhxRGp0bUxrSkbwQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '200 Jackson St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['200 Jackson St',
#                                                   'San Francisco, CA 94111'],
#                               'state': 'CA',
#                               'zip_code': '94111'},
#                  'name': 'Kokkari Estiatorio',
#                  'phone': '+14159810983',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 4264,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/kokkari-estiatorio-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'nopa-san-francisco',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'modern_european',
#                                  'title': 'Modern European'},
#                                 {'alias': 'desserts', 'title': 'Desserts'}],
#                  'coordinates': {'latitude': 37.77483, 'longitude': -122.43746},
#                  'display_phone': '(415) 864-8643',
#                  'distance': 1559.1831881623302,
#                  'id': 'ttarnopezxmp2ROB1N2PaA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6YAWg-LlK25yC3Fw0g-E9g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '560 Divisadero St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['560 Divisadero St',
#                                                   'San Francisco, CA 94117'],
#                               'state': 'CA',
#                               'zip_code': '94117'},
#                  'name': 'Nopa',
#                  'phone': '+14158648643',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 4858,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/nopa-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'san-tung-san-francisco-2',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'chicken_wings',
#                                  'title': 'Chicken Wings'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 37.76367, 'longitude': -122.46896},
#                  'display_phone': '(415) 242-0828',
#                  'distance': 2877.9920007894843,
#                  'id': 'M0JTO3oyu6gxh1mfFjU-dA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LTtoZ25m8FX1UV37asnTCw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1031 Irving St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['1031 Irving St',
#                                                   'San Francisco, CA 94122'],
#                               'state': 'CA',
#                               'zip_code': '94122'},
#                  'name': 'San Tung',
#                  'phone': '+14152420828',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 6313,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/san-tung-san-francisco-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'el-farolito-san-francisco-2',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                  'coordinates': {'latitude': 37.75265, 'longitude': -122.41812},
#                  'display_phone': '(415) 824-7877',
#                  'distance': 1845.9442151607977,
#                  'id': 'SGRmnarrNuVEsAjYdEoA0w',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OPnKCvgBR2-lQ1-yahrpiA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2779 Mission St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['2779 Mission St',
#                                                   'San Francisco, CA 94110'],
#                               'state': 'CA',
#                               'zip_code': '94110'},
#                  'name': 'El Farolito',
#                  'phone': '+14158247877',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 4572,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/el-farolito-san-francisco-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'b-patisserie-san-francisco-2',
#                  'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#                                 {'alias': 'cakeshop',
#                                  'title': 'Patisserie/Cake Shop'},
#                                 {'alias': 'macarons', 'title': 'Macarons'}],
#                  'coordinates': {'latitude': 37.78783, 'longitude': -122.44073},
#                  'display_phone': '(415) 440-1700',
#                  'distance': 3024.692512860378,
#                  'id': '2XQm-uFcTS7oc8MFP-8olA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/M5q0Ur83lVDj9umOvs8XOw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2821 California St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['2821 California St',
#                                                   'San Francisco, CA 94115'],
#                               'state': 'CA',
#                               'zip_code': '94115'},
#                  'name': 'B Patisserie',
#                  'phone': '+14154401700',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 2192,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/b-patisserie-san-francisco-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'zazie-san-francisco',
#                  'categories': [{'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'french', 'title': 'French'}],
#                  'coordinates': {'latitude': 37.765244,
#                                  'longitude': -122.4501138},
#                  'display_phone': '(415) 564-5332',
#                  'distance': 1294.8624343961546,
#                  'id': 'gqVl3RprESEqkIPeJH0yOg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-Um7shUxZYZzq8rB6X4q9g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '941 Cole St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['941 Cole St',
#                                                   'San Francisco, CA 94117'],
#                               'state': 'CA',
#                               'zip_code': '94117'},
#                  'name': 'Zazie',
#                  'phone': '+14155645332',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 4102,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/zazie-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'fog-harbor-fish-house-san-francisco-2',
#                  'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'bars', 'title': 'Bars'}],
#                  'coordinates': {'latitude': 37.809041,
#                                  'longitude': -122.410233},
#                  'display_phone': '(415) 421-2442',
#                  'distance': 5827.740044156521,
#                  'id': 'f-m7-hyFzkf0HSEeQ2s-9A',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Lv7tIRX3Bim9bKqtWifmNg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': 'Pier 39',
#                               'address2': 'Ste A-202',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['Pier 39',
#                                                   'Ste A-202',
#                                                   'San Francisco, CA 94133'],
#                               'state': 'CA',
#                               'zip_code': '94133'},
#                  'name': 'Fog Harbor Fish House',
#                  'phone': '+14154212442',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 4868,
#                  'transactions': ['restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/fog-harbor-fish-house-san-francisco-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'saigon-sandwich-san-francisco',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#                  'coordinates': {'latitude': 37.7831519576568,
#                                  'longitude': -122.417318022037},
#                  'display_phone': '(415) 474-5698',
#                  'distance': 2991.557987577475,
#                  'id': 'hqQoVK0vadOX7_4gN1sh3g',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lVyf1pn7ft4YzO2n4z7Exg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '560 Larkin St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['560 Larkin St',
#                                                   'San Francisco, CA 94102'],
#                               'state': 'CA',
#                               'zip_code': '94102'},
#                  'name': 'Saigon Sandwich',
#                  'phone': '+14154745698',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 3100,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/saigon-sandwich-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'foreign-cinema-san-francisco',
#                  'categories': [{'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'mediterranean',
#                                  'title': 'Mediterranean'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'}],
#                  'coordinates': {'latitude': 37.75637, 'longitude': -122.41925},
#                  'display_phone': '(415) 648-7600',
#                  'distance': 1597.7572216192718,
#                  'id': 'n6L5VIGunR51-D55C-eYeQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cw5y2LSOIE-EVNjKK_d7SQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2534 Mission St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['2534 Mission St',
#                                                   'San Francisco, CA 94110'],
#                               'state': 'CA',
#                               'zip_code': '94110'},
#                  'name': 'Foreign Cinema',
#                  'phone': '+14156487600',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 4567,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/foreign-cinema-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'golden-boy-pizza-san-francisco',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'italian', 'title': 'Italian'}],
#                  'coordinates': {'latitude': 37.7997956,
#                                  'longitude': -122.4080729},
#                  'display_phone': '(415) 982-9738',
#                  'distance': 4992.437696561071,
#                  'id': 'PTFxtXS47ZVRCdZIrEWvGw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/F8OxoXdS51h2VfU9Je2cNQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '542 Green St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['542 Green St',
#                                                   'San Francisco, CA 94133'],
#                               'state': 'CA',
#                               'zip_code': '94133'},
#                  'name': 'Golden Boy Pizza',
#                  'phone': '+14159829738',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 3139,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/golden-boy-pizza-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'liholiho-yacht-club-san-francisco-2',
#                  'categories': [{'alias': 'bars', 'title': 'Bars'},
#                                 {'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'seafood', 'title': 'Seafood'}],
#                  'coordinates': {'latitude': 37.78818, 'longitude': -122.41458},
#                  'display_phone': '(415) 440-5446',
#                  'distance': 3596.036080023175,
#                  'id': 'KkAVX3Wb7E3lP5F_f_8pXg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FK2X98w6z5naJyiQjsGTNA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '871 Sutter St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['871 Sutter St',
#                                                   'San Francisco, CA 94109'],
#                               'state': 'CA',
#                               'zip_code': '94109'},
#                  'name': 'Liholiho Yacht Club',
#                  'phone': '+14154405446',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 1978,
#                  'transactions': ['restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/liholiho-yacht-club-san-francisco-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'little-star-pizza-san-francisco',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#                  'coordinates': {'latitude': 37.77753, 'longitude': -122.43798},
#                  'display_phone': '(415) 441-1118',
#                  'distance': 1854.973403198051,
#                  'id': '__I9HmtBMV4dDkEgT22V4g',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C-lgf5TcabWh0YvlTAGGTw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '846 Divisadero St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['846 Divisadero St',
#                                                   'San Francisco, CA 94117'],
#                               'state': 'CA',
#                               'zip_code': '94117'},
#                  'name': 'Little Star Pizza',
#                  'phone': '+14154411118',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 2789,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/little-star-pizza-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'sotto-mare-oysteria-and-seafood-san-francisco',
#                  'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'italian', 'title': 'Italian'},
#                                 {'alias': 'bars', 'title': 'Bars'}],
#                  'coordinates': {'latitude': 37.79979, 'longitude': -122.40834},
#                  'display_phone': '(415) 398-3181',
#                  'distance': 4980.8804673363975,
#                  'id': '8dUaybEPHsZMgr1iKgqgMQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Efr_0zx4ID9jla5kxuIMNQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '552 Green St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['552 Green St',
#                                                   'San Francisco, CA 94133'],
#                               'state': 'CA',
#                               'zip_code': '94133'},
#                  'name': 'Sotto Mare Oysteria & Seafood',
#                  'phone': '+14153983181',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 3300,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/sotto-mare-oysteria-and-seafood-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'sweet-maple-san-francisco',
#                  'categories': [{'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#                  'coordinates': {'latitude': 37.785735681426,
#                                  'longitude': -122.43507770852},
#                  'display_phone': '(415) 655-9169',
#                  'distance': 2764.2882648857435,
#                  'id': '-DrR38H1Abk0wCyu9XOLug',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LElE7KG2v6y_OR1W05o-1Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2101 Sutter St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['2101 Sutter St',
#                                                   'San Francisco, CA 94115'],
#                               'state': 'CA',
#                               'zip_code': '94115'},
#                  'name': 'Sweet Maple',
#                  'phone': '+14156559169',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 3163,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/sweet-maple-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'tonys-pizza-napoletana-san-francisco',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'italian', 'title': 'Italian'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'}],
#                  'coordinates': {'latitude': 37.8003315377662,
#                                  'longitude': -122.409053979377},
#                  'display_phone': '(415) 835-9888',
#                  'distance': 5002.084940639829,
#                  'id': 'mSMZJj2pFvttWLpcDmgrEA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/B8ZBnH5ORGXz2OblCb1owQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1570 Stockton St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['1570 Stockton St',
#                                                   'San Francisco, CA 94133'],
#                               'state': 'CA',
#                               'zip_code': '94133'},
#                  'name': "Tony's Pizza Napoletana",
#                  'phone': '+14158359888',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 4404,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/tonys-pizza-napoletana-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'humphry-slocombe-ice-cream-san-francisco',
#                  'categories': [{'alias': 'icecream',
#                                  'title': 'Ice Cream & Frozen Yogurt'}],
#                  'coordinates': {'latitude': 37.75279, 'longitude': -122.4122},
#                  'display_phone': '(415) 550-6971',
#                  'distance': 2316.757442605059,
#                  'id': '47OC_X6KkiDDQ4jwoCUjFg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IExOCfX-PyH--tLJkTgstQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2790A Harrison St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['2790A Harrison St',
#                                                   'San Francisco, CA 94110'],
#                               'state': 'CA',
#                               'zip_code': '94110'},
#                  'name': 'Humphry Slocombe Ice Cream',
#                  'phone': '+14155506971',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 3312,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/humphry-slocombe-ice-cream-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'mamas-on-washington-square-san-francisco',
#                  'categories': [{'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'}],
#                  'coordinates': {'latitude': 37.801606,
#                                  'longitude': -122.409599},
#                  'display_phone': '(415) 362-6421',
#                  'distance': 5104.4332229025,
#                  'id': 'MvAo0hj9FXOeNL5PwBZ0fQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ETJbHf1tlPkn5V-EKjsmLw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1701 Stockton St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['1701 Stockton St',
#                                                   'San Francisco, CA 94133'],
#                               'state': 'CA',
#                               'zip_code': '94133'},
#                  'name': "Mama's On Washington Square",
#                  'phone': '+14153626421',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 4001,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mamas-on-washington-square-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'chapeau-san-francisco',
#                  'categories': [{'alias': 'french', 'title': 'French'},
#                                 {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#                  'coordinates': {'latitude': 37.78327, 'longitude': -122.46066},
#                  'display_phone': '(415) 750-9787',
#                  'distance': 3278.53001624654,
#                  'id': 'L5vSeC_sa3TUQW_lticqyA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wrugBy0ez8LEo-cOYhWa8Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '126 Clement St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['126 Clement St',
#                                                   'San Francisco, CA 94118'],
#                               'state': 'CA',
#                               'zip_code': '94118'},
#                  'name': 'Chapeau!',
#                  'phone': '+14157509787',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 2605,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/chapeau-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'the-codmother-fish-and-chips-san-francisco-3',
#                  'categories': [{'alias': 'british', 'title': 'British'},
#                                 {'alias': 'fishnchips',
#                                  'title': 'Fish & Chips'},
#                                 {'alias': 'seafood', 'title': 'Seafood'}],
#                  'coordinates': {'latitude': 37.8072702557489,
#                                  'longitude': -122.417093771758},
#                  'display_phone': '(415) 606-9349',
#                  'distance': 5429.459284841022,
#                  'id': 'PDhfVvcVXgBinZf5I6s1KQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jIiYLWAA1S-efjnkLJ29FQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '496 Beach St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['496 Beach St',
#                                                   'San Francisco, CA 94133'],
#                               'state': 'CA',
#                               'zip_code': '94133'},
#                  'name': 'The Codmother Fish and Chips',
#                  'phone': '+14156069349',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 2767,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-codmother-fish-and-chips-san-francisco-3?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'golden-gate-bridge-san-francisco',
#                  'categories': [{'alias': 'landmarks',
#                                  'title': 'Landmarks & Historical Buildings'}],
#                  'coordinates': {'latitude': 37.8165970086601,
#                                  'longitude': -122.47807463501},
#                  'display_phone': '(415) 921-5858',
#                  'distance': 7192.893507137584,
#                  'id': 'Lz7ydUVmsr2DekT9enEhvw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m-wvW5F9KIcysf8BsaEu4w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['San Francisco, CA 94129'],
#                               'state': 'CA',
#                               'zip_code': '94129'},
#                  'name': 'Golden Gate Bridge',
#                  'phone': '+14159215858',
#                  'rating': 4.5,
#                  'review_count': 1784,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/golden-gate-bridge-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'la-taqueria-san-francisco-2',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                  'coordinates': {'latitude': 37.750883,
#                                  'longitude': -122.418123},
#                  'display_phone': '(415) 285-7117',
#                  'distance': 1958.4726910319168,
#                  'id': 'JARsJVKLPgs_yC3cwDnp7g',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/quJVkgOw_pf70_enWelldw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2889 Mission St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['2889 Mission St',
#                                                   'San Francisco, CA 94110'],
#                               'state': 'CA',
#                               'zip_code': '94110'},
#                  'name': 'La Taqueria',
#                  'phone': '+14152857117',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 3680,
#                  'transactions': [],
# ...
#                 {'alias': 'schuberts-bakery-san-francisco',
#                  'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#                                 {'alias': 'desserts', 'title': 'Desserts'}],
#                  'coordinates': {'latitude': 37.78267, 'longitude': -122.46493},
#                  'display_phone': '(415) 752-1580',
#                  'distance': 3492.5239262642963,
#                  'id': 'DyXoC_NhJW0Xx5j_OPQRHQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VpmSb6NkMu96C5z9-7OFGQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '521 Clement St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['521 Clement St',
#                                                   'San Francisco, CA 94118'],
#                               'state': 'CA',
#                               'zip_code': '94118'},
#                  'name': "Schubert's Bakery",
#                  'phone': '+14157521580',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 1593,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/schuberts-bakery-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'golden-gate-park-san-francisco',
#                  'categories': [{'alias': 'parks', 'title': 'Parks'}],
#                  'coordinates': {'latitude': 37.770518,
#                                  'longitude': -122.479878},
#                  'display_phone': '(415) 831-2700',
#                  'distance': 3964.6442334683065,
#                  'id': 'KIVq5BlJKTipwtB3NATX0g',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/H49aHxUhiXpFT6bOWkRkbg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '501 Stanyan St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['501 Stanyan St',
#                                                   'San Francisco, CA 94117'],
#                               'state': 'CA',
#                               'zip_code': '94117'},
#                  'name': 'Golden Gate Park',
#                  'phone': '+14158312700',
#                  'rating': 4.5,
#                  'review_count': 1135,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/golden-gate-park-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'anthonys-cookies-san-francisco-2',
#                  'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 37.7502, 'longitude': -122.42013},
#                  'display_phone': '(415) 655-9834',
#                  'distance': 1846.7743188995664,
#                  'id': 'PrlH7YcQ22m9DyuWbxJjMA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XB4w12f7O649xt5bNmvUGA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1417 Valencia St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['1417 Valencia St',
#                                                   'San Francisco, CA 94110'],
#                               'state': 'CA',
#                               'zip_code': '94110'},
#                  'name': "Anthony's Cookies",
#                  'phone': '+14156559834',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 1605,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/anthonys-cookies-san-francisco-2?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'alcatraz-island-san-francisco-3',
#                  'categories': [{'alias': 'museums', 'title': 'Museums'},
#                                 {'alias': 'landmarks',
#                                  'title': 'Landmarks & Historical Buildings'}],
#                  'coordinates': {'latitude': 37.8269684873863,
#                                  'longitude': -122.422947920859},
#                  'display_phone': '(415) 561-4900',
#                  'distance': 7441.681017402877,
#                  'id': 'Y12NJdzfE-33OQtoHmomMw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FblALGKxi_VaN-h99n_FyA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': 'B201 Fort Mason',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['B201 Fort Mason',
#                                                   'San Francisco, CA 94122'],
#                               'state': 'CA',
#                               'zip_code': '94122'},
#                  'name': 'Alcatraz Island',
#                  'phone': '+14155614900',
#                  'rating': 4.5,
#                  'review_count': 1615,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/alcatraz-island-san-francisco-3?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'hrd-san-francisco-4',
#                  'categories': [{'alias': 'korean', 'title': 'Korean'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'},
#                                 {'alias': 'mexican', 'title': 'Mexican'}],
#                  'coordinates': {'latitude': 37.7811065758548,
#                                  'longitude': -122.395329724426},
#                  'display_phone': '(415) 543-2355',
#                  'distance': 4255.584833618084,
#                  'id': 'bUr4iq2mKKiBOu2HKynylg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PyFG7Chlw7mH5IX7WZDVcA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '521A 3rd St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['521A 3rd St',
#                                                   'San Francisco, CA 94107'],
#                               'state': 'CA',
#                               'zip_code': '94107'},
#                  'name': 'HRD',
#                  'phone': '+14155432355',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 2388,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/hrd-san-francisco-4?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'marufuku-ramen-sf-san-francisco',
#                  'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#                  'coordinates': {'latitude': 37.785155,
#                                  'longitude': -122.432075},
#                  'display_phone': '(415) 872-9786',
#                  'distance': 2724.336436836609,
#                  'id': 'HHtpR0RslupSQ99GIIwW5A',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2lUFO5HWD7_RLDWlT5Nvuw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1581 Webster St',
#                               'address2': 'Ste 235',
#                               'address3': None,
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['1581 Webster St',
#                                                   'Ste 235',
#                                                   'San Francisco, CA 94115'],
#                               'state': 'CA',
#                               'zip_code': '94115'},
#                  'name': 'Marufuku Ramen SF',
#                  'phone': '+14158729786',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 1754,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/marufuku-ramen-sf-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'kitchen-story-san-francisco',
#                  'categories': [{'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'},
#                                 {'alias': 'newamerican',
#                                  'title': 'American (New)'}],
#                  'coordinates': {'latitude': 37.7642352,
#                                  'longitude': -122.4306936},
#                  'display_phone': '(415) 525-4905',
#                  'distance': 625.1566435901884,
#                  'id': 'XQLmEdXoMzOpffwoFaBtaQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/s03_G5k_GvH9P-rfIAtqhQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3499 16th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['3499 16th St',
#                                                   'San Francisco, CA 94114'],
#                               'state': 'CA',
#                               'zip_code': '94114'},
#                  'name': 'Kitchen Story',
#                  'phone': '+14155254905',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 2786,
#                  'transactions': ['restaurant_reservation', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/kitchen-story-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'swan-oyster-depot-san-francisco',
#                  'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#                  'coordinates': {'latitude': 37.790939,
#                                  'longitude': -122.420796},
#                  'display_phone': '(415) 673-1101',
#                  'distance': 3612.4047165830657,
#                  'id': 'eI0DpD2Xx8hFlk7eAdFCqQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bTNQr5_BJPblsEwJZK2Y5w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1517 Polk St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['1517 Polk St',
#                                                   'San Francisco, CA 94109'],
#                               'state': 'CA',
#                               'zip_code': '94109'},
#                  'name': 'Swan Oyster Depot',
#                  'phone': '+14156731101',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 2567,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/swan-oyster-depot-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'anchor-oyster-bar-san-francisco',
#                  'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#                  'coordinates': {'latitude': 37.759689,
#                                  'longitude': -122.434609},
#                  'display_phone': '(415) 431-3990',
#                  'distance': 210.29727091545175,
#                  'id': 'ZDvIMjJ-7I0561ckM4pAeA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-Zw6ivl7HlQ7ELe0OnPJFQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '579 Castro St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['579 Castro St',
#                                                   'San Francisco, CA 94114'],
#                               'state': 'CA',
#                               'zip_code': '94114'},
#                  'name': 'Anchor Oyster Bar',
#                  'phone': '+14154313990',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 1402,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/anchor-oyster-bar-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'},
#                 {'alias': 'marco-polo-italian-ice-cream-san-francisco',
#                  'categories': [{'alias': 'icecream',
#                                  'title': 'Ice Cream & Frozen Yogurt'},
#                                 {'alias': 'gelato', 'title': 'Gelato'},
#                                 {'alias': 'desserts', 'title': 'Desserts'}],
#                  'coordinates': {'latitude': 37.7426223,
#                                  'longitude': -122.481885},
#                  'display_phone': '(415) 731-2833',
#                  'distance': 4480.698934510479,
#                  'id': 'RrIduU6-SUNCanTEVF-hIQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7Iq2HsBFpW3MdTBp6LikBA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1447 Taraval St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Francisco',
#                               'country': 'US',
#                               'display_address': ['1447 Taraval St',
#                                                   'San Francisco, CA 94116'],
#                               'state': 'CA',
#                               'zip_code': '94116'},
#                  'name': 'Marco Polo Italian Ice Cream',
#                  'phone': '+14157312833',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 1373,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/marco-polo-italian-ice-cream-san-francisco?adjust_creative=wg4vS75UWcL_5IfcnZsmOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wg4vS75UWcL_5IfcnZsmOg'}],
#  'region': {'center': {'latitude': 37.76089938976322,
#                        'longitude': -122.43644714355469}},
#  'total': 6800}

# %%
# Lists
business_names_list = []
categories_list = []
street_address_list = []
city_list = []
country_list = []
ratings_list = []
review_count_list = []
price_ratings = []

# Looping through each business in the call
for businesses in api_call["businesses"]:
    try:
        # Name
        name = businesses["name"]
        print(f"Successfully found business name: {name}")

        # Category 
        category = businesses["categories"][0]["alias"]
        print(f"Successfully found category: {category}")

        # Street Address
        street_address = businesses["location"]["address1"]
        print(f"Successfully found street address: {street_address}")

        # City
        # city = businesses["location"]["city"]
        print(f"Successfully found city: {city}")

        # Country
        country = businesses["location"]["country"]
        print(f"Successfully found country: {country}")

        # Price rating
        # NOTE: Some places do not have a price rating (ie. $, $$, $$$)
        price = businesses["price"]
        print(f"Successfully found price rating: {price}")

        # Ratings
        rating = businesses["rating"]
        print(f"Successfully found rating: {rating}")

        # Review count
        review_count = businesses["review_count"]
        print(f"Successfully found review counts: {review_count}")
        
        # Appends
        # Tried putting appends after each section, adding them towards the end made it work 
        # with no error since it passes those without a price rating
        business_names_list.append(name) 
        categories_list.append(category)
        street_address_list.append(street_address)
        city_list.append(city)
        country_list.append(country)
        price_ratings.append(price)
        ratings_list.append(rating)
        review_count_list.append(review_count)
        
        print("- - - - - - - - - - - - - - - - - - - - - -")
    except Exception:
        pass
# Out:
# Successfully found business name: Bi-Rite Creamery
# Successfully found category: icecream
# Successfully found street address: 3692 18th St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $
# Successfully found rating: 4.5
# Successfully found review counts: 9419
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Brenda's French Soul Food
# Successfully found category: breakfast_brunch
# Successfully found street address: 652 Polk St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.0
# Successfully found review counts: 10098
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Gary Danko
# Successfully found category: newamerican
# Successfully found street address: 800 N Point St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$$$
# Successfully found rating: 4.5
# Successfully found review counts: 5267
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Tartine Bakery & Cafe
# Successfully found category: bakeries
# Successfully found street address: 600 Guerrero St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.0
# Successfully found review counts: 7496
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Mitchell's Ice Cream
# Successfully found category: icecream
# Successfully found street address: 688 San Jose Ave
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $
# Successfully found rating: 4.5
# Successfully found review counts: 3763
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Hog Island Oyster Co
# Successfully found category: seafood
# Successfully found street address: 1 Ferry Bldg
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.5
# Successfully found review counts: 5468
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: House of Prime Rib
# Successfully found category: tradamerican
# Successfully found street address: 1906 Van Ness Ave
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$$
# Successfully found rating: 4.0
# Successfully found review counts: 6660
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Burma Superstar
# Successfully found category: burmese
# Successfully found street address: 309 Clement St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.0
# Successfully found review counts: 6406
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: The House
# Successfully found category: asianfusion
# Successfully found street address: 1230 Grant Ave
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$$
# Successfully found rating: 4.5
# Successfully found review counts: 4473
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Kokkari Estiatorio
# Successfully found category: greek
# Successfully found street address: 200 Jackson St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$$
# Successfully found rating: 4.5
# Successfully found review counts: 4264
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Nopa
# Successfully found category: newamerican
# Successfully found street address: 560 Divisadero St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$$
# Successfully found rating: 4.0
# Successfully found review counts: 4858
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: San Tung
# Successfully found category: chinese
# Successfully found street address: 1031 Irving St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.0
# Successfully found review counts: 6313
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: El Farolito
# Successfully found category: mexican
# Successfully found street address: 2779 Mission St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $
# Successfully found rating: 4.0
# Successfully found review counts: 4572
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: B Patisserie
# Successfully found category: bakeries
# Successfully found street address: 2821 California St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.5
# Successfully found review counts: 2192
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Zazie
# Successfully found category: breakfast_brunch
# Successfully found street address: 941 Cole St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.0
# Successfully found review counts: 4102
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Fog Harbor Fish House
# Successfully found category: seafood
# Successfully found street address: Pier 39
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.0
# Successfully found review counts: 4868
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Saigon Sandwich
# Successfully found category: vietnamese
# Successfully found street address: 560 Larkin St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $
# Successfully found rating: 4.5
# Successfully found review counts: 3100
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Foreign Cinema
# Successfully found category: breakfast_brunch
# Successfully found street address: 2534 Mission St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$$
# Successfully found rating: 4.0
# Successfully found review counts: 4567
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Golden Boy Pizza
# Successfully found category: pizza
# Successfully found street address: 542 Green St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $
# Successfully found rating: 4.5
# Successfully found review counts: 3139
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Liholiho Yacht Club
# Successfully found category: bars
# Successfully found street address: 871 Sutter St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$$
# Successfully found rating: 4.5
# Successfully found review counts: 1978
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Little Star Pizza
# Successfully found category: pizza
# Successfully found street address: 846 Divisadero St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.5
# Successfully found review counts: 2789
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Sotto Mare Oysteria & Seafood
# Successfully found category: seafood
# Successfully found street address: 552 Green St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.5
# Successfully found review counts: 3300
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Sweet Maple
# Successfully found category: tradamerican
# Successfully found street address: 2101 Sutter St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.0
# Successfully found review counts: 3163
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Tony's Pizza Napoletana
# Successfully found category: pizza
# Successfully found street address: 1570 Stockton St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.0
# Successfully found review counts: 4404
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Humphry Slocombe Ice Cream
# Successfully found category: icecream
# Successfully found street address: 2790A Harrison St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $
# Successfully found rating: 4.0
# Successfully found review counts: 3312
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Mama's On Washington Square
# Successfully found category: breakfast_brunch
# Successfully found street address: 1701 Stockton St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.0
# Successfully found review counts: 4001
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Chapeau!
# Successfully found category: french
# Successfully found street address: 126 Clement St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$$
# Successfully found rating: 4.5
# Successfully found review counts: 2605
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: The Codmother Fish and Chips
# Successfully found category: british
# Successfully found street address: 496 Beach St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $
# Successfully found rating: 4.5
# Successfully found review counts: 2767
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Golden Gate Bridge
# Successfully found category: landmarks
# Successfully found street address:
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found business name: La Taqueria
# Successfully found category: mexican
# Successfully found street address: 2889 Mission St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $
# Successfully found rating: 4.0
# Successfully found review counts: 3680
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Bob's Donut & Pastry Shop
# Successfully found category: bakeries
# Successfully found street address: 1621 Polk St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $
# Successfully found rating: 4.5
# Successfully found review counts: 2738
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Twin Peaks
# Successfully found category: parks
# Successfully found street address: 501 Twin Peaks Blvd
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found business name: Espetus Brazilian Steak House
# Successfully found category: steak
# Successfully found street address: 1686 Market St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$$
# Successfully found rating: 4.0
# Successfully found review counts: 3218
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Arizmendi Bakery
# Successfully found category: bakeries
# Successfully found street address: 1331 9th Ave
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $
# Successfully found rating: 4.5
# Successfully found review counts: 1828
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Dottie's True Blue Cafe
# Successfully found category: tradamerican
# Successfully found street address: 28 6th St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.0
# Successfully found review counts: 4182
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: State Bird Provisions
# Successfully found category: tapasmallplates
# Successfully found street address: 1529 Fillmore St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$$
# Successfully found rating: 4.0
# Successfully found review counts: 2531
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Mission Dolores Park
# Successfully found category: parks
# Successfully found street address: 19th & Dolores St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found business name: Philz Coffee
# Successfully found category: coffee
# Successfully found street address: 3101 24th St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $
# Successfully found rating: 4.5
# Successfully found review counts: 1634
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Suppenküche
# Successfully found category: german
# Successfully found street address: 525 Laguna St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.0
# Successfully found review counts: 3027
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Beretta
# Successfully found category: italian
# Successfully found street address: 1199 Valencia St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.0
# Successfully found review counts: 3386
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Schubert's Bakery
# Successfully found category: bakeries
# Successfully found street address: 521 Clement St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.5
# Successfully found review counts: 1593
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Golden Gate Park
# Successfully found category: parks
# Successfully found street address: 501 Stanyan St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found business name: Anthony's Cookies
# Successfully found category: bakeries
# Successfully found street address: 1417 Valencia St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $
# Successfully found rating: 4.5
# Successfully found review counts: 1605
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Alcatraz Island
# Successfully found category: museums
# Successfully found street address: B201 Fort Mason
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found business name: HRD
# Successfully found category: korean
# Successfully found street address: 521A 3rd St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.0
# Successfully found review counts: 2388
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Marufuku Ramen SF
# Successfully found category: ramen
# Successfully found street address: 1581 Webster St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.5
# Successfully found review counts: 1754
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Kitchen Story
# Successfully found category: breakfast_brunch
# Successfully found street address: 3499 16th St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.0
# Successfully found review counts: 2786
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Swan Oyster Depot
# Successfully found category: seafood
# Successfully found street address: 1517 Polk St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$
# Successfully found rating: 4.0
# Successfully found review counts: 2567
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Anchor Oyster Bar
# Successfully found category: seafood
# Successfully found street address: 579 Castro St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $$$
# Successfully found rating: 4.5
# Successfully found review counts: 1402
# - - - - - - - - - - - - - - - - - - - - - -
# Successfully found business name: Marco Polo Italian Ice Cream
# Successfully found category: icecream
# Successfully found street address: 1447 Taraval St
# Successfully found city: Los Angeles
# Successfully found country: US
# Successfully found price rating: $
# Successfully found rating: 4.5
# Successfully found review counts: 1373
# - - - - - - - - - - - - - - - - - - - - - -

# %% [markdown]
# # Yelp DataFrame

# %%
# Dictionary for DataFrame
business_details_dict = ({"Name": business_names_list,
                          "Category": categories_list,
                          "Street": street_address_list,
                          "City": city_list,
                          "Country": country_list,
                          "Rating": ratings_list,
                          "Review Count": review_count_list,
                          "$": price_ratings})

# Dictionary to DataFrame
yelp_df = pd.DataFrame(business_details_dict)
yelp_df.head(50)
# Out:
#                              Name          Category              Street  \
# 0                Bi-Rite Creamery          icecream        3692 18th St
# 1       Brenda's French Soul Food  breakfast_brunch         652 Polk St
# 2                      Gary Danko       newamerican      800 N Point St
# 3           Tartine Bakery & Cafe          bakeries     600 Guerrero St
# 4            Mitchell's Ice Cream          icecream    688 San Jose Ave
# 5            Hog Island Oyster Co           seafood        1 Ferry Bldg
# 6              House of Prime Rib      tradamerican   1906 Van Ness Ave
# 7                 Burma Superstar           burmese      309 Clement St
# 8                       The House       asianfusion      1230 Grant Ave
# 9              Kokkari Estiatorio             greek      200 Jackson St
# 10                           Nopa       newamerican   560 Divisadero St
# 11                       San Tung           chinese      1031 Irving St
# 12                    El Farolito           mexican     2779 Mission St
# 13                   B Patisserie          bakeries  2821 California St
# 14                          Zazie  breakfast_brunch         941 Cole St
# 15          Fog Harbor Fish House           seafood             Pier 39
# 16                Saigon Sandwich        vietnamese       560 Larkin St
# 17                 Foreign Cinema  breakfast_brunch     2534 Mission St
# 18               Golden Boy Pizza             pizza        542 Green St
# 19            Liholiho Yacht Club              bars       871 Sutter St
# 20              Little Star Pizza             pizza   846 Divisadero St
# 21  Sotto Mare Oysteria & Seafood           seafood        552 Green St
# 22                    Sweet Maple      tradamerican      2101 Sutter St
# 23        Tony's Pizza Napoletana             pizza    1570 Stockton St
# 24     Humphry Slocombe Ice Cream          icecream   2790A Harrison St
# 25    Mama's On Washington Square  breakfast_brunch    1701 Stockton St
# 26                       Chapeau!            french      126 Clement St
# 27   The Codmother Fish and Chips           british        496 Beach St
# 28                    La Taqueria           mexican     2889 Mission St
# 29      Bob's Donut & Pastry Shop          bakeries        1621 Polk St
# 30  Espetus Brazilian Steak House             steak      1686 Market St
# 31               Arizmendi Bakery          bakeries        1331 9th Ave
# 32        Dottie's True Blue Cafe      tradamerican           28 6th St
# 33          State Bird Provisions   tapasmallplates    1529 Fillmore St
# 34                   Philz Coffee            coffee        3101 24th St
# 35                    Suppenküche            german       525 Laguna St
# 36                        Beretta           italian    1199 Valencia St
# 37              Schubert's Bakery          bakeries      521 Clement St
# 38              Anthony's Cookies          bakeries    1417 Valencia St
# 39                            HRD            korean         521A 3rd St
# 40              Marufuku Ramen SF             ramen     1581 Webster St
# 41                  Kitchen Story  breakfast_brunch        3499 16th St
# 42              Swan Oyster Depot           seafood        1517 Polk St
# 43              Anchor Oyster Bar           seafood       579 Castro St
# 44   Marco Polo Italian Ice Cream          icecream     1447 Taraval St
#
#            City Country  Rating  Review Count     $
# 0   Los Angeles      US     4.5          9419     $
# 1   Los Angeles      US     4.0         10098    $$
# 2   Los Angeles      US     4.5          5267  $$$$
# 3   Los Angeles      US     4.0          7496    $$
# 4   Los Angeles      US     4.5          3763     $
# 5   Los Angeles      US     4.5          5468    $$
# 6   Los Angeles      US     4.0          6660   $$$
# 7   Los Angeles      US     4.0          6406    $$
# 8   Los Angeles      US     4.5          4473   $$$
# 9   Los Angeles      US     4.5          4264   $$$
# 10  Los Angeles      US     4.0          4858   $$$
# 11  Los Angeles      US     4.0          6313    $$
# 12  Los Angeles      US     4.0          4572     $
# 13  Los Angeles      US     4.5          2192    $$
# 14  Los Angeles      US     4.0          4102    $$
# 15  Los Angeles      US     4.0          4868    $$
# 16  Los Angeles      US     4.5          3100     $
# 17  Los Angeles      US     4.0          4567   $$$
# 18  Los Angeles      US     4.5          3139     $
# 19  Los Angeles      US     4.5          1978   $$$
# 20  Los Angeles      US     4.5          2789    $$
# 21  Los Angeles      US     4.5          3300    $$
# 22  Los Angeles      US     4.0          3163    $$
# 23  Los Angeles      US     4.0          4404    $$
# 24  Los Angeles      US     4.0          3312     $
# 25  Los Angeles      US     4.0          4001    $$
# 26  Los Angeles      US     4.5          2605   $$$
# 27  Los Angeles      US     4.5          2767     $
# 28  Los Angeles      US     4.0          3680     $
# 29  Los Angeles      US     4.5          2738     $
# 30  Los Angeles      US     4.0          3218   $$$
# 31  Los Angeles      US     4.5          1828     $
# 32  Los Angeles      US     4.0          4182    $$
# 33  Los Angeles      US     4.0          2531   $$$
# 34  Los Angeles      US     4.5          1634     $
# 35  Los Angeles      US     4.0          3027    $$
# 36  Los Angeles      US     4.0          3386    $$
# 37  Los Angeles      US     4.5          1593    $$
# 38  Los Angeles      US     4.5          1605     $
# 39  Los Angeles      US     4.0          2388    $$
# 40  Los Angeles      US     4.5          1754    $$
# 41  Los Angeles      US     4.0          2786    $$
# 42  Los Angeles      US     4.0          2567    $$
# 43  Los Angeles      US     4.5          1402   $$$
# 44  Los Angeles      US     4.5          1373     $

# %% [markdown]
# # Category Shares

# %%
# Counting up number in each category
biz_categories = yelp_df.groupby("Category").count()
# Resetting the index to Category
biz_categories.reset_index("Category", inplace=True)
categories = biz_categories["Category"]

# Labels for each category to be used in Plotly 
labels = categories

# Values for each category to be used in Plotly
category_count = biz_categories["Name"]
values = category_count
values

# Setting up arguments for Plotly pie chart 
trace = go.Pie(labels=labels, values=values)

py.iplot([trace], filename= "Pie_Chart_Categories")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~nguyenkevint94/74.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Price Comparisons

# %%
# Grouping price ratings ($)
price_groups = yelp_df.groupby("$").count()
price_groups.reset_index("$", inplace=True)

labels = price_groups["$"]
values = price_groups["Name"]

trace = go.Pie(labels=labels, values=values)

py.iplot([trace], filename= "Pie_Chart_Price_Categories")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~nguyenkevint94/76.embed" height="525px" width="100%"></iframe>
