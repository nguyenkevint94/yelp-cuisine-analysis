# %% [markdown]
# # Dependencies

# %%
# Dependencies
import pandas as pd
import re
import requests
import math 
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from pprint import pprint
from config import api_key, plotly_key
from yelpapi import YelpAPI

# %% [markdown]
# # Ideas
# <ul><li>Average rating vs. category
# <li>Average rating vs. price rating
# <li>Number of restaurant categories per city
# <li>Review Count vs. city

# %% [markdown]
# # Useful Links
# <ul><li><a href="https://alcidanalytics.com/p/geographic-heatmap-in-python">Heat maps</a>

# %% [markdown]
# # API Call

# %%
# API call to Yelp API
yelp_api = YelpAPI(api_key)
# Input string for location search
input_string = input("Search query: ")
api_call = yelp_api.search_query(location=input_string, limit=50)

# API Call to Plotly 
plotly.tools.set_credentials_file(username='nguyenkevint94', api_key=plotly_key)

# Delete hashtag to view the contents of api_call
# pprint(api_call)
# Out:
# Search query: Santa Monica, CA

# %%
# Lists
business_names_list = []
categories_list = []
street_address_list = []
city_list = []
country_list = []
ratings_list = []
review_count_list = []
price_ratings = []

# Looping through each business in the call
for businesses in api_call["businesses"]:
    try:
        # Name
        name = businesses["name"]
        # print(f"Successfully found business name: {name}")

        # Category 
        category = businesses["categories"][0]["alias"]
        # print(f"Successfully found category: {category}")

        # Street Address
        street_address = businesses["location"]["address1"]
        # print(f"Successfully found street address: {street_address}")

        # City
        city = businesses["location"]["city"]
        # print(f"Successfully found city: {city}")

        # Country
        country = businesses["location"]["country"]
        # print(f"Successfully found country: {country}")

        # Price rating
        # NOTE: Some places do not have a price rating (ie. $, $$, $$$)
        price = businesses["price"]
        # print(f"Successfully found price rating: {price}")

        # Ratings
        rating = businesses["rating"]
        # print(f"Successfully found rating: {rating}")

        # Review count
        review_count = businesses["review_count"]
        # print(f"Successfully found review counts: {review_count}")
        
        # Appends
        # Tried putting appends after each section, adding them towards the end made it work 
        # with no error since it passes those without a price rating
        business_names_list.append(name) 
        categories_list.append(category)
        street_address_list.append(street_address)
        city_list.append(city)
        country_list.append(country)
        price_ratings.append(price)
        ratings_list.append(rating)
        review_count_list.append(review_count)
        
        # print("- - - - - - - - - - - - - - - - - - - - - -")
    except Exception:
        pass

# %% [markdown]
# # Yelp DataFrame

# %%
# Dictionary for DataFrame
business_details_dict = ({"Name": business_names_list,
                          "Category": categories_list,
                          "Street": street_address_list,
                          "City": city_list,
                          "Country": country_list,
                          "Rating": ratings_list,
                          "Review Count": review_count_list,
                          "$": price_ratings})

# Dictionary to DataFrame
yelp_df = pd.DataFrame(business_details_dict)
yelp_df
# Out:
#                                   Name          Category  \
# 0              Bay Cities Italian Deli             delis
# 1                          Tar & Roses       newamerican
# 2          The Misfit Restaurant + Bar              bars
# 3                         Philz Coffee            coffee
# 4                         Fritto Misto           italian
# 5           Sidecar Doughnuts & Coffee            donuts
# 6            Urth Caffé - Santa Monica  breakfast_brunch
# 7   Benny's Tacos & Chicken Rotisserie           mexican
# 8                    True Food Kitchen       newamerican
# 9                           Sunny Blue          japanese
# 10                DK's Donuts & Bakery            donuts
# 11                     Father's Office           burgers
# 12           SUGARFISH by sushi nozawa             sushi
# 13                          Upper West       newamerican
# 14                  Rocco's Cheesecake          desserts
# 15                             Mélisse       newamerican
# 16         Umami Burger - Santa Monica           burgers
# 17            Water Grill-Santa Monica           seafood
# 18                         The Lobster              bars
# 19                        Bru's Wiffle  breakfast_brunch
# 20                     Cha Cha Chicken         caribbean
# 21                  Seasalt Fish Grill           seafood
# 22                   Santa Monica Pier    amusementparks
# 23                      Milo and Olive             pizza
# 24       Forma Restaurant & Cheese Bar           italian
# 25                        The Albright           seafood
# 26                 Shaka Shack Burgers           burgers
# 27                         Funnel Mill            coffee
# 28                Mercado Santa Monica           mexican
# 29            Pono Burger Santa Monica           burgers
# 30     Satdha Plant-Based Thai Kitchen              thai
# 31                         Cookie Good          bakeries
# 32                       Sweetfin Poké          hawaiian
# 33                            Manchego           spanish
# 34            The Counter Santa Monica           burgers
# 35                         R+D Kitchen       newamerican
# 36                     Tacos Por Favor           mexican
# 37          Amelia's Espresso & Panini            coffee
# 38                Santa Monica Seafood    seafoodmarkets
# 39                       The Penthouse       newamerican
# 40         Hungry Pocket Falafel House        mideastern
# 41                      BOA Steakhouse             steak
# 42                  Ingo's Tasty Diner       newamerican
# 43                             Crimson     mediterranean
# 44                         Huckleberry  breakfast_brunch
# 45                          Blue Daisy         creperies
# 46              Third Street Promenade   shoppingcenters
# 47                     Enterprise Fish           seafood
# 48                       Rustic Canyon              bars
# 49                              Cassia       singaporean
#
#                     Street          City Country  Rating  Review Count     $
# 0        1517 Lincoln Blvd  Santa Monica      US     4.0          4340     $
# 1    602 Santa Monica Blvd  Santa Monica      US     4.5          1986   $$$
# 2    225 Santa Monica Blvd  Santa Monica      US     4.0          3573    $$
# 3    525 Santa Monica Blvd  Santa Monica      US     4.5          1572     $
# 4         601 Colorado Ave  Santa Monica      US     4.5          2265    $$
# 5        631 Wilshire Blvd  Santa Monica      US     4.5          1487    $$
# 6             2327 Main St  Santa Monica      US     4.0          3082    $$
# 7        915 Wilshire Blvd  Santa Monica      US     4.5          1397     $
# 8      395 Santa Monica Pl  Santa Monica      US     4.0          2102    $$
# 9             2728 Main St  Santa Monica      US     4.5          1202     $
# 10  1614 Santa Monica Blvd  Santa Monica      US     4.0          1935     $
# 11        1018 Montana Ave  Santa Monica      US     4.0          2995    $$
# 12             1345 2nd St  Santa Monica      US     4.0          1605   $$$
# 13          3321 Pico Blvd  Santa Monica      US     4.0          1740    $$
# 14          1701 Pico Blvd  Santa Monica      US     5.0           486    $$
# 15      1104 Wilshire Blvd  Santa Monica      US     4.0          1216  $$$$
# 16            525 Broadway  Santa Monica      US     4.0          2445    $$
# 17          1401 Ocean Ave  Santa Monica      US     4.0          1632   $$$
# 18          1602 Ocean Ave  Santa Monica      US     4.0          2069   $$$
# 19      2408 Wilshire Blvd  Santa Monica      US     4.0          1791    $$
# 20          1906 Ocean Ave  Santa Monica      US     4.0          1920    $$
# 21   508 Santa Monica Blvd  Santa Monica      US     4.0          1176    $$
# 22   200 Santa Monica Pier  Santa Monica      US     4.0          1736    $$
# 23      2723 Wilshire Blvd  Santa Monica      US     4.0          1581    $$
# 24        1610 Montana Ave  Santa Monica      US     4.5           829   $$$
# 25   258 Santa Monica Pier  Santa Monica      US     4.0          1240    $$
# 26    1701 Ocean Park Blvd  Santa Monica      US     4.5           766    $$
# 27            930 Broadway  Santa Monica      US     4.5           690    $$
# 28             1416 4th St  Santa Monica      US     4.0          1304    $$
# 29            829 Broadway  Santa Monica      US     4.0          1044    $$
# 30       2218 Lincoln Blvd  Santa Monica      US     4.5           652    $$
# 31      2448 Wilshire Blvd  Santa Monica      US     4.5           397    $$
# 32            829 Broadway  Santa Monica      US     4.0          1086    $$
# 33            2518 Main St  Santa Monica      US     4.5           731    $$
# 34    2901 Ocean Park Blvd  Santa Monica      US     4.0          1520    $$
# 35        1323 Montana Ave  Santa Monica      US     4.0          1223    $$
# 36       1408 Olympic Blvd  Santa Monica      US     4.0          1452     $
# 37            2645 Main St  Santa Monica      US     4.5           467    $$
# 38      1000 Wilshire Blvd  Santa Monica      US     4.0          1338    $$
# 39             1111 2nd St  Santa Monica      US     3.5          1758   $$$
# 40          1715 Pico Blvd  Santa Monica      US     4.5           775     $
# 41   101 Santa Monica Blvd  Santa Monica      US     4.0          1247   $$$
# 42      1213 Wilshire Blvd  Santa Monica      US     4.5           538    $$
# 43    2901 Ocean Park Blvd  Santa Monica      US     4.5           765    $$
# 44      1014 Wilshire Blvd  Santa Monica      US     3.5          1925    $$
# 45            609 Broadway  Santa Monica      US     4.0          1277    $$
# 46   1351 3rd St Promenade  Santa Monica      US     4.0           895    $$
# 47           174 Kinney St  Santa Monica      US     3.5          1770    $$
# 48      1119 Wilshire Blvd  Santa Monica      US     4.0          1179   $$$
# 49             1314 7th St  Santa Monica      US     4.0           918   $$$

# %% [markdown]
# # Sorting by Review Count

# %%
sorted_df_reviews = yelp_df.sort_values(by=["Review Count"], ascending=False)
sorted_df_reviews
# Out:
#                                   Name          Category  \
# 0              Bay Cities Italian Deli             delis
# 2          The Misfit Restaurant + Bar              bars
# 6            Urth Caffé - Santa Monica  breakfast_brunch
# 11                     Father's Office           burgers
# 16         Umami Burger - Santa Monica           burgers
# 4                         Fritto Misto           italian
# 8                    True Food Kitchen       newamerican
# 18                         The Lobster              bars
# 1                          Tar & Roses       newamerican
# 10                DK's Donuts & Bakery            donuts
# 44                         Huckleberry  breakfast_brunch
# 20                     Cha Cha Chicken         caribbean
# 19                        Bru's Wiffle  breakfast_brunch
# 47                     Enterprise Fish           seafood
# 39                       The Penthouse       newamerican
# 13                          Upper West       newamerican
# 22                   Santa Monica Pier    amusementparks
# 17            Water Grill-Santa Monica           seafood
# 12           SUGARFISH by sushi nozawa             sushi
# 23                      Milo and Olive             pizza
# 3                         Philz Coffee            coffee
# 34            The Counter Santa Monica           burgers
# 5           Sidecar Doughnuts & Coffee            donuts
# 36                     Tacos Por Favor           mexican
# 7   Benny's Tacos & Chicken Rotisserie           mexican
# 38                Santa Monica Seafood    seafoodmarkets
# 28                Mercado Santa Monica           mexican
# 45                          Blue Daisy         creperies
# 41                      BOA Steakhouse             steak
# 25                        The Albright           seafood
# 35                         R+D Kitchen       newamerican
# 15                             Mélisse       newamerican
# 9                           Sunny Blue          japanese
# 48                       Rustic Canyon              bars
# 21                  Seasalt Fish Grill           seafood
# 32                       Sweetfin Poké          hawaiian
# 29            Pono Burger Santa Monica           burgers
# 49                              Cassia       singaporean
# 46              Third Street Promenade   shoppingcenters
# 24       Forma Restaurant & Cheese Bar           italian
# 40         Hungry Pocket Falafel House        mideastern
# 26                 Shaka Shack Burgers           burgers
# 43                             Crimson     mediterranean
# 33                            Manchego           spanish
# 27                         Funnel Mill            coffee
# 30     Satdha Plant-Based Thai Kitchen              thai
# 42                  Ingo's Tasty Diner       newamerican
# 14                  Rocco's Cheesecake          desserts
# 37          Amelia's Espresso & Panini            coffee
# 31                         Cookie Good          bakeries
#
#                     Street          City Country  Rating  Review Count     $
# 0        1517 Lincoln Blvd  Santa Monica      US     4.0          4340     $
# 2    225 Santa Monica Blvd  Santa Monica      US     4.0          3573    $$
# 6             2327 Main St  Santa Monica      US     4.0          3082    $$
# 11        1018 Montana Ave  Santa Monica      US     4.0          2995    $$
# 16            525 Broadway  Santa Monica      US     4.0          2445    $$
# 4         601 Colorado Ave  Santa Monica      US     4.5          2265    $$
# 8      395 Santa Monica Pl  Santa Monica      US     4.0          2102    $$
# 18          1602 Ocean Ave  Santa Monica      US     4.0          2069   $$$
# 1    602 Santa Monica Blvd  Santa Monica      US     4.5          1986   $$$
# 10  1614 Santa Monica Blvd  Santa Monica      US     4.0          1935     $
# 44      1014 Wilshire Blvd  Santa Monica      US     3.5          1925    $$
# 20          1906 Ocean Ave  Santa Monica      US     4.0          1920    $$
# 19      2408 Wilshire Blvd  Santa Monica      US     4.0          1791    $$
# 47           174 Kinney St  Santa Monica      US     3.5          1770    $$
# 39             1111 2nd St  Santa Monica      US     3.5          1758   $$$
# 13          3321 Pico Blvd  Santa Monica      US     4.0          1740    $$
# 22   200 Santa Monica Pier  Santa Monica      US     4.0          1736    $$
# 17          1401 Ocean Ave  Santa Monica      US     4.0          1632   $$$
# 12             1345 2nd St  Santa Monica      US     4.0          1605   $$$
# 23      2723 Wilshire Blvd  Santa Monica      US     4.0          1581    $$
# 3    525 Santa Monica Blvd  Santa Monica      US     4.5          1572     $
# 34    2901 Ocean Park Blvd  Santa Monica      US     4.0          1520    $$
# 5        631 Wilshire Blvd  Santa Monica      US     4.5          1487    $$
# 36       1408 Olympic Blvd  Santa Monica      US     4.0          1452     $
# 7        915 Wilshire Blvd  Santa Monica      US     4.5          1397     $
# 38      1000 Wilshire Blvd  Santa Monica      US     4.0          1338    $$
# 28             1416 4th St  Santa Monica      US     4.0          1304    $$
# 45            609 Broadway  Santa Monica      US     4.0          1277    $$
# 41   101 Santa Monica Blvd  Santa Monica      US     4.0          1247   $$$
# 25   258 Santa Monica Pier  Santa Monica      US     4.0          1240    $$
# 35        1323 Montana Ave  Santa Monica      US     4.0          1223    $$
# 15      1104 Wilshire Blvd  Santa Monica      US     4.0          1216  $$$$
# 9             2728 Main St  Santa Monica      US     4.5          1202     $
# 48      1119 Wilshire Blvd  Santa Monica      US     4.0          1179   $$$
# 21   508 Santa Monica Blvd  Santa Monica      US     4.0          1176    $$
# 32            829 Broadway  Santa Monica      US     4.0          1086    $$
# 29            829 Broadway  Santa Monica      US     4.0          1044    $$
# 49             1314 7th St  Santa Monica      US     4.0           918   $$$
# 46   1351 3rd St Promenade  Santa Monica      US     4.0           895    $$
# 24        1610 Montana Ave  Santa Monica      US     4.5           829   $$$
# 40          1715 Pico Blvd  Santa Monica      US     4.5           775     $
# 26    1701 Ocean Park Blvd  Santa Monica      US     4.5           766    $$
# 43    2901 Ocean Park Blvd  Santa Monica      US     4.5           765    $$
# 33            2518 Main St  Santa Monica      US     4.5           731    $$
# 27            930 Broadway  Santa Monica      US     4.5           690    $$
# 30       2218 Lincoln Blvd  Santa Monica      US     4.5           652    $$
# 42      1213 Wilshire Blvd  Santa Monica      US     4.5           538    $$
# 14          1701 Pico Blvd  Santa Monica      US     5.0           486    $$
# 37            2645 Main St  Santa Monica      US     4.5           467    $$
# 31      2448 Wilshire Blvd  Santa Monica      US     4.5           397    $$

# %% [markdown]
# # Category Shares

# %%
# Counting up number in each category
biz_categories = yelp_df.groupby("Category").count()
# Resetting the index to Category
biz_categories.reset_index("Category", inplace=True)
categories = biz_categories["Category"]

# Labels for each category to be used in Plotly 
labels = categories

# Values for each category to be used in Plotly
category_count = biz_categories["Name"]
values = category_count
values

# Setting up arguments for Plotly pie chart 
trace = go.Pie(labels=labels, values=values)

py.iplot([trace], filename= "Pie_Chart_Categories")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~nguyenkevint94/82.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Price Comparisons

# %%
# Grouping price ratings ($)
price_groups = yelp_df.groupby("$").count()
price_groups.reset_index("$", inplace=True)

labels = price_groups["$"]
values = price_groups["Name"]

trace = go.Pie(labels=labels, values=values)

py.iplot([trace], filename= "Pie_Chart_Price_Categories")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~nguyenkevint94/84.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Average Review Count vs. Category

# %%
# Grouping categories 
average_reviews = yelp_df.groupby("Category").mean()
average_reviews.reset_index("Category")

# Gathering top 5 categories with the highest number of reviews
top_five = average_reviews.nlargest(10,"Review Count")
top_five.reset_index("Category", inplace=True)
# Category names
categories = top_five["Category"]

# Category review counts
review_count = top_five["Review Count"]

# Setting up the bar chart
trace = go.Bar(
    x=categories,
    y=review_count,
    text=categories,
    marker=dict(
        color="rgb(158, 202, 225)",
        line=dict(
            color="rgb(8, 48,107)",
            width=1.5,
        )
    ),
    opacity=0.6
)

data=[trace]
layout=go.Layout(
    title="Top 10 Categories by Average Review Count",
)

# Bar chart 
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="top-10-categories-by-average-review-count")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~nguyenkevint94/88.embed" height="525px" width="100%"></iframe>
