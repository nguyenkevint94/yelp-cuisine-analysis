# %% [markdown]
# # Dependencies

# %%
# Dependencies
import pandas as pd
import re
import requests
import math 
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from pprint import pprint
from config import api_key, plotly_key
from yelpapi import YelpAPI

# %% [markdown]
# # Ideas
# <ul><li>Average rating vs. category
# <li>Average rating vs. price rating
# <li>Number of restaurant categories per city
# <li>Review Count vs. city

# %% [markdown]
# # API Call

# %%
# API call to Yelp API
yelp_api = YelpAPI(api_key)
# Input string for location search
input_string = input("Search query: ")
api_call = yelp_api.search_query(location=input_string, limit=50)

# API Call to Plotly 
plotly.tools.set_credentials_file(username='nguyenkevint94', api_key=plotly_key)

# Delete hashtag to view the contents of api_call
# pprint(api_call)
# Out:
# Search query: Orange County, CA

# %%
# Lists
business_names_list = []
categories_list = []
street_address_list = []
city_list = []
country_list = []
ratings_list = []
review_count_list = []
price_ratings = []

# Looping through each business in the call
for businesses in api_call["businesses"]:
    try:
        # Name
        name = businesses["name"]
        # print(f"Successfully found business name: {name}")

        # Category 
        category = businesses["categories"][0]["alias"]
        # print(f"Successfully found category: {category}")

        # Street Address
        street_address = businesses["location"]["address1"]
        # print(f"Successfully found street address: {street_address}")

        # City
        city = businesses["location"]["city"]
        # print(f"Successfully found city: {city}")

        # Country
        country = businesses["location"]["country"]
        # print(f"Successfully found country: {country}")

        # Price rating
        # NOTE: Some places do not have a price rating (ie. $, $$, $$$)
        price = businesses["price"]
        # print(f"Successfully found price rating: {price}")

        # Ratings
        rating = businesses["rating"]
        # print(f"Successfully found rating: {rating}")

        # Review count
        review_count = businesses["review_count"]
        # print(f"Successfully found review counts: {review_count}")
        
        # Appends
        # Tried putting appends after each section, adding them towards the end made it work 
        # with no error since it passes those without a price rating
        business_names_list.append(name) 
        categories_list.append(category)
        street_address_list.append(street_address)
        city_list.append(city)
        country_list.append(country)
        price_ratings.append(price)
        ratings_list.append(rating)
        review_count_list.append(review_count)
        
        # print("- - - - - - - - - - - - - - - - - - - - - -")
    except Exception:
        pass

# %% [markdown]
# # Yelp DataFrame

# %%
# Dictionary for DataFrame
business_details_dict = ({"Name": business_names_list,
                          "Category": categories_list,
                          "Street": street_address_list,
                          "City": city_list,
                          "Country": country_list,
                          "Rating": ratings_list,
                          "Review Count": review_count_list,
                          "$": price_ratings})

# Dictionary to DataFrame
yelp_df = pd.DataFrame(business_details_dict)
yelp_df
# Out:
#                                     Name          Category  \
# 0                   Taqueria El Zamorano  breakfast_brunch
# 1                              Cream Pan          bakeries
# 2                     Cauldron Ice Cream          icecream
# 3                             Playground       newamerican
# 4          Ritter's Steam Kettle Cooking             cajun
# 5                         Chicken Maison     mediterranean
# 6                    Mastro's Steakhouse             steak
# 7                           Din Tai Fung         taiwanese
# 8                       85°C Bakery Cafe            coffee
# 9                 Peter's Gourmade Grill           burgers
# 10                         Nate's Korner  breakfast_brunch
# 11                            Seasons 52       newamerican
# 12  Hokkaido Ramen Santouka - Costa Mesa             ramen
# 13                Kitakata Ramen Ban Nai             ramen
# 14         Bosscat Kitchen and Libations       newamerican
# 15                       Baja Fish Tacos           seafood
# 16             Istanbul Grill California     mediterranean
# 17                    The Capital Grille             steak
# 18                       The Vox Kitchen        vietnamese
# 19                                 Anjin          japanese
# 20                  HiroNori Craft Ramen             ramen
# 21                        Playground 2.0   tapasmallplates
# 22                                Habana             cuban
# 23                      Crave Restaurant       newamerican
# 24                  Gen Korean BBQ House            korean
# 25                          North Italia             pizza
# 26               Maggiano's Little Italy           italian
# 27              Hans' Homemade Ice Cream          icecream
# 28                             Blue Bowl         juicebars
# 29                           Lola Gaspar             latin
# 30                             Mil Jugos        venezuelan
# 31        Water Grill- South Coast Plaza           seafood
# 32                      Seabirds Kitchen             vegan
# 33                    Spicy Noodle House              thai
# 34                            Bella Cuba             cuban
# 35                                Pueblo   tapasmallplates
# 36                                Bruxie        sandwiches
# 37        Native Foods Cafe - Costa Mesa        vegetarian
# 38                        The BurgerStop      tradamerican
# 39                          Milk & Honey            coffee
# 40         Chapter One: the modern local              bars
# 41                         Old Vine Cafe       newamerican
# 42                 Sabroso Mexican Grill           mexican
# 43                       HONDA-YA Tustin             sushi
# 44                          Kaizen Shabu            hotpot
# 45          Karl Strauss Brewing Company       newamerican
# 46                            Euro Caffe            coffee
# 47                       Shabu Shabu Bar          japanese
# 48        Confetti Italian Ice & Custard          desserts
# 49                              Hug Life          icecream
#
#                    Street             City Country  Rating  Review Count     $
# 0        925 W Warner Ave        Santa Ana      US     4.5          1061     $
# 1      602 El Camino Real           Tustin      US     4.5          4333     $
# 2   1421 W MacArthur Blvd        Santa Ana      US     4.0          2614     $
# 3            220 E 4th St        Santa Ana      US     4.5          2894    $$
# 4   1421 W MacArthur Blvd        Santa Ana      US     4.0          2455    $$
# 5       3332 S Bristol St        Santa Ana      US     4.5          1840     $
# 6          633 Anton Blvd       Costa Mesa      US     4.0          3020  $$$$
# 7         3333 Bristol St       Costa Mesa      US     4.0          3844    $$
# 8         2700 Alton Pkwy           Irvine      US     4.0          5530     $
# 9       14311 Newport Ave           Tustin      US     4.5          2212     $
# 10         3960 S Main St        Santa Ana      US     4.0          1829     $
# 11        3333 Bristol St       Costa Mesa      US     4.0          2410    $$
# 12      665 Paularino Ave       Costa Mesa      US     4.0          2216     $
# 13           891 Baker St       Costa Mesa      US     4.5          1908    $$
# 14    4647 MacArthur Blvd    Newport Beach      US     4.5          2905    $$
# 15      3664 S Bristol St        Santa Ana      US     4.0          1393     $
# 16       18010 Newhope St  Fountain Valley      US     4.5          1698    $$
# 17        3333 Bristol St       Costa Mesa      US     4.5          1507   $$$
# 18    16161 Brookhurst St  Fountain Valley      US     4.5          2493    $$
# 19        3033 Bristol St       Costa Mesa      US     4.5          1502    $$
# 20      2222 Michelson Dr           Irvine      US     4.5          1662    $$
# 21           220 E 4th St        Santa Ana      US     5.0           463  $$$$
# 22        2930 Bristol St       Costa Mesa      US     4.0          3508    $$
# 23           410 W 4th St        Santa Ana      US     4.0          1234    $$
# 24      13741 Newport Ave           Tustin      US     4.0          4020    $$
# 25      2957 Michelson Dr           Irvine      US     4.5          2391    $$
# 26        3333 Bristol St       Costa Mesa      US     4.0          2289    $$
# 27      3640 S Bristol St        Santa Ana      US     4.0          1058     $
# 28          417 S Main St           Orange      US     5.0          1264     $
# 29           211 W 2nd St        Santa Ana      US     4.0          1728    $$
# 30           320 W 5th St        Santa Ana      US     4.5          1072     $
# 31         3300 Bristol S       Costa Mesa      US     4.0          1479   $$$
# 32        2930 Bristol St       Costa Mesa      US     4.5          1381    $$
# 33      3314 S Bristol St        Santa Ana      US     4.5           686     $
# 34      3940 S Bristol St        Santa Ana      US     4.0          1188    $$
# 35        3321 Hyland Ave       Costa Mesa      US     4.5          1301    $$
# 36      292 N Glassell St           Orange      US     4.0          3960     $
# 37        2937 Bristol St       Costa Mesa      US     4.0          1615    $$
# 38        2302 S Broadway        Santa Ana      US     4.5           413     $
# 39        2981 Bristol St       Costa Mesa      US     4.0          2291     $
# 40         227 N Broadway        Santa Ana      US     3.5          2234    $$
# 41        2937 Bristol St       Costa Mesa      US     4.0          1954    $$
# 42      13129 Harbor Blvd     Garden Grove      US     4.5          2524    $$
# 43     556 El Camino Real           Tustin      US     4.0          2067    $$
# 44      303 N Spurgeon St        Santa Ana      US     4.5           458    $$
# 45         901 S Coast Dr       Costa Mesa      US     4.0          1207    $$
# 46      3950 S Bristol St        Santa Ana      US     4.0          1001     $
# 47         1945 E 17th St        Santa Ana      US     4.0          1793    $$
# 48          1175 Baker St       Costa Mesa      US     4.5          1112     $
# 49        14241 Euclid St     Garden Grove      US     5.0           846     $

# %% [markdown]
# # Sorting by Review Count

# %%
sorted_df_reviews = yelp_df.sort_values(by=["Review Count"], ascending=False)
sorted_df_reviews
# Out:
#                                     Name          Category  \
# 8                       85°C Bakery Cafe            coffee
# 1                              Cream Pan          bakeries
# 24                  Gen Korean BBQ House            korean
# 36                                Bruxie        sandwiches
# 7                           Din Tai Fung         taiwanese
# 22                                Habana             cuban
# 6                    Mastro's Steakhouse             steak
# 14         Bosscat Kitchen and Libations       newamerican
# 3                             Playground       newamerican
# 2                     Cauldron Ice Cream          icecream
# 42                 Sabroso Mexican Grill           mexican
# 18                       The Vox Kitchen        vietnamese
# 4          Ritter's Steam Kettle Cooking             cajun
# 11                            Seasons 52       newamerican
# 25                          North Italia             pizza
# 39                          Milk & Honey            coffee
# 26               Maggiano's Little Italy           italian
# 40         Chapter One: the modern local              bars
# 12  Hokkaido Ramen Santouka - Costa Mesa             ramen
# 9                 Peter's Gourmade Grill           burgers
# 43                       HONDA-YA Tustin             sushi
# 41                         Old Vine Cafe       newamerican
# 13                Kitakata Ramen Ban Nai             ramen
# 5                         Chicken Maison     mediterranean
# 10                         Nate's Korner  breakfast_brunch
# 47                       Shabu Shabu Bar          japanese
# 29                           Lola Gaspar             latin
# 16             Istanbul Grill California     mediterranean
# 20                  HiroNori Craft Ramen             ramen
# 37        Native Foods Cafe - Costa Mesa        vegetarian
# 17                    The Capital Grille             steak
# 19                                 Anjin          japanese
# 31        Water Grill- South Coast Plaza           seafood
# 15                       Baja Fish Tacos           seafood
# 32                      Seabirds Kitchen             vegan
# 35                                Pueblo   tapasmallplates
# 28                             Blue Bowl         juicebars
# 23                      Crave Restaurant       newamerican
# 45          Karl Strauss Brewing Company       newamerican
# 34                            Bella Cuba             cuban
# 48        Confetti Italian Ice & Custard          desserts
# 30                             Mil Jugos        venezuelan
# 0                   Taqueria El Zamorano  breakfast_brunch
# 27              Hans' Homemade Ice Cream          icecream
# 46                            Euro Caffe            coffee
# 49                              Hug Life          icecream
# 33                    Spicy Noodle House              thai
# 21                        Playground 2.0   tapasmallplates
# 44                          Kaizen Shabu            hotpot
# 38                        The BurgerStop      tradamerican
#
#                    Street             City Country  Rating  Review Count     $
# 8         2700 Alton Pkwy           Irvine      US     4.0          5530     $
# 1      602 El Camino Real           Tustin      US     4.5          4333     $
# 24      13741 Newport Ave           Tustin      US     4.0          4020    $$
# 36      292 N Glassell St           Orange      US     4.0          3960     $
# 7         3333 Bristol St       Costa Mesa      US     4.0          3844    $$
# 22        2930 Bristol St       Costa Mesa      US     4.0          3508    $$
# 6          633 Anton Blvd       Costa Mesa      US     4.0          3020  $$$$
# 14    4647 MacArthur Blvd    Newport Beach      US     4.5          2905    $$
# 3            220 E 4th St        Santa Ana      US     4.5          2894    $$
# 2   1421 W MacArthur Blvd        Santa Ana      US     4.0          2614     $
# 42      13129 Harbor Blvd     Garden Grove      US     4.5          2524    $$
# 18    16161 Brookhurst St  Fountain Valley      US     4.5          2493    $$
# 4   1421 W MacArthur Blvd        Santa Ana      US     4.0          2455    $$
# 11        3333 Bristol St       Costa Mesa      US     4.0          2410    $$
# 25      2957 Michelson Dr           Irvine      US     4.5          2391    $$
# 39        2981 Bristol St       Costa Mesa      US     4.0          2291     $
# 26        3333 Bristol St       Costa Mesa      US     4.0          2289    $$
# 40         227 N Broadway        Santa Ana      US     3.5          2234    $$
# 12      665 Paularino Ave       Costa Mesa      US     4.0          2216     $
# 9       14311 Newport Ave           Tustin      US     4.5          2212     $
# 43     556 El Camino Real           Tustin      US     4.0          2067    $$
# 41        2937 Bristol St       Costa Mesa      US     4.0          1954    $$
# 13           891 Baker St       Costa Mesa      US     4.5          1908    $$
# 5       3332 S Bristol St        Santa Ana      US     4.5          1840     $
# 10         3960 S Main St        Santa Ana      US     4.0          1829     $
# 47         1945 E 17th St        Santa Ana      US     4.0          1793    $$
# 29           211 W 2nd St        Santa Ana      US     4.0          1728    $$
# 16       18010 Newhope St  Fountain Valley      US     4.5          1698    $$
# 20      2222 Michelson Dr           Irvine      US     4.5          1662    $$
# 37        2937 Bristol St       Costa Mesa      US     4.0          1615    $$
# 17        3333 Bristol St       Costa Mesa      US     4.5          1507   $$$
# 19        3033 Bristol St       Costa Mesa      US     4.5          1502    $$
# 31         3300 Bristol S       Costa Mesa      US     4.0          1479   $$$
# 15      3664 S Bristol St        Santa Ana      US     4.0          1393     $
# 32        2930 Bristol St       Costa Mesa      US     4.5          1381    $$
# 35        3321 Hyland Ave       Costa Mesa      US     4.5          1301    $$
# 28          417 S Main St           Orange      US     5.0          1264     $
# 23           410 W 4th St        Santa Ana      US     4.0          1234    $$
# 45         901 S Coast Dr       Costa Mesa      US     4.0          1207    $$
# 34      3940 S Bristol St        Santa Ana      US     4.0          1188    $$
# 48          1175 Baker St       Costa Mesa      US     4.5          1112     $
# 30           320 W 5th St        Santa Ana      US     4.5          1072     $
# 0        925 W Warner Ave        Santa Ana      US     4.5          1061     $
# 27      3640 S Bristol St        Santa Ana      US     4.0          1058     $
# 46      3950 S Bristol St        Santa Ana      US     4.0          1001     $
# 49        14241 Euclid St     Garden Grove      US     5.0           846     $
# 33      3314 S Bristol St        Santa Ana      US     4.5           686     $
# 21           220 E 4th St        Santa Ana      US     5.0           463  $$$$
# 44      303 N Spurgeon St        Santa Ana      US     4.5           458    $$
# 38        2302 S Broadway        Santa Ana      US     4.5           413     $

# %% [markdown]
# # Category Shares

# %%
# Counting up number in each category
biz_categories = yelp_df.groupby("Category").count()
# Resetting the index to Category
biz_categories.reset_index("Category", inplace=True)
categories = biz_categories["Category"]

# Labels for each category to be used in Plotly 
labels = categories

# Values for each category to be used in Plotly
category_count = biz_categories["Name"]
values = category_count
values

# Setting up arguments for Plotly pie chart 
trace = go.Pie(labels=labels, values=values)

py.iplot([trace], filename= "Pie_Chart_Categories")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~nguyenkevint94/82.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Price Comparisons

# %%
# Grouping price ratings ($)
price_groups = yelp_df.groupby("$").count()
price_groups.reset_index("$", inplace=True)

labels = price_groups["$"]
values = price_groups["Name"]

trace = go.Pie(labels=labels, values=values)

py.iplot([trace], filename= "Pie_Chart_Price_Categories")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~nguyenkevint94/84.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Average Review Count vs. Category

# %%
# Grouping categories 
average_reviews = yelp_df.groupby("Category").mean()
average_reviews.reset_index("Category")

# Gathering top 5 categories with the highest number of reviews
top_five = average_reviews.nlargest(5,"Review Count")
top_five.reset_index("Category", inplace=True)
# Category names
categories = top_five["Category"]

# Category review counts
review_count = top_five["Review Count"]

# Setting up the bar chart
trace = go.Bar(
    x=categories,
    y=review_count,
    text=categories,
    marker=dict(
        color="rgb(158, 202, 225)",
        line=dict(
            color="rgb(8, 48,107)",
            width=1.5,
        )
    ),
    opacity=0.6
)

data=[trace]
layout=go.Layout(
    title="Top 5 Categories by Average Review Count",
)

# Bar chart 
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="top-5-categories-by-average-review-count")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~nguyenkevint94/86.embed" height="525px" width="100%"></iframe>
